# %% [markdown]
# #Assignment 2 - Transliteration

# %% [markdown]
# In this task you are required to solve the transliteration problem of names from English to Russian. Transliteration of a string means writing this string using the alphabet of another language with the preservation of pronunciation, although not always.

# %% [markdown]
# ## 0. Instructions

# %% [markdown]
# To complete the assignment please do the following  steps (all the three are requred to get the full credits):
#
# 1. **Notebook**. Upload to Canvas a filled notebook with answers (this file).
# Please enter the questions inside this notebook where appropriate in the designated cells.
#
# 2. **Scripts**. In *Practical* part of this notebook you will be asked to implement a transformer-based approach for transliteration. Upload to Canvas your code which implements solution to this part in the form of *.py file (not *.ipynb notebooks) of the model:
#
#   - ``translit.py``
#
# This script should have the specific structure as it is shown in the baseline soultion [here](https://github.com/skoltech-nlp/filimdb_evaluation/blob/master/translit_baseline.py). So, you should implement your ``train`` and ``classify`` functions. Your model should be implemented as a special class/function in this script (be sure if you add any outer dependencies that everything is improted correctly and can be reproducable).
#
# Please make sure that you code does not contain any dependencies which are specific to your system.
#
#   *Important*: to make sure everything works, please use ONLY the following software configuration (no matter which operating system you use): Anaconda 2020.07  distribution for Python 3.8 and PyTorch 1.3. The preferred way to install PyTorch is "conda install -c pytorch pytorch" and Torchtext is "conda install -c pytorch torchtext". There should be no additional libraries used: Anaconda already provides a sufficient number of them. If you need something just select from these available. Test for no the absence of dependencies by creating a virtual environment.
#
# 3. **Shared task.** After the implementation of models' architectures you are asked to participate in the [competition](https://competitions.codalab.org/competitions/30932) to solve **Transliteration** task using your implemented code. **Important: indicate your team as 'Skoltech'!**
#
# You should use your transliteration scripts from the previous part to train, validate, and generate predictions for the public (Practice) and private (Evaluation) test sets. For this you should use [``evaluate_translit.py``](https://github.com/skoltech-nlp/filimdb_evaluation/blob/master/evaluate_translit.py) script.
#
# It will produce predictions (``preds_translit.tsv``) for the dataset and score them if the true answers are present. You can use these scores to evaluate your model on dev set and choose the best one. Be sure:
#
# 1. To download the [dataset](https://github.com/skoltech-nlp/filimdb_evaluation/blob/master/TRANSLIT.tar.gz) and unzip it in the same folder where ``evaluate_translit.py`` is.
# 2. to put your ``translit.py`` and ``evaluate_translit.py`` scripts in the same folder.
# 3. to change importing in ``evaluate_translit.py`` from ``translit_baseline`` import ``train, classify`` to ``from translit import train, classify``.
#
# If you work in Colab you can dowload data and scripts with ``wget`` command and run them from notebook cells.
#
# Upload obtained TSV file with your predictions (``preds_translit.tsv``) in ``.zip`` for the best results to both phases of the competition.
#
# Please, provide here in the notebook your user name in Codalab competition that we can recognize you in the leaderboard.

# %%
# !wget https://raw.githubusercontent.com/skoltech-nlp/filimdb_evaluation/master/evaluate_translit.py
# Out:
# --2022-05-12 07:32:00--  https://raw.githubusercontent.com/skoltech-nlp/filimdb_evaluation/master/evaluate_translit.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1349 (1.3K) [text/plain]
# Saving to: ‘evaluate_translit.py’
#
# evaluate_translit.p 100%[===================>]   1.32K  --.-KB/s    in 0s
#
# 2022-05-12 07:32:00 (45.7 MB/s) - ‘evaluate_translit.py’ saved [1349/1349]

# %% [markdown]
# **YOUR USERNAME IN THE CODALAB LEADERBOARD:**

# %% [markdown]
# ```
#
# pkrajput7
#
# ```

# %% [markdown]
# ##1. Theoretical part
# Solve the following theoretical subtasks:

# %% [markdown]
# ###1.1 Normalization

# %% [markdown]
# * The main part of transformer architecture is MultiHeadAttention. This layer is breafly explained in subsection 2.2, its logic is described with formulas:
# $$
# Attention(Q, K, V)=softmax\left(\frac{Q K^{T}}{\sqrt{d_{k}}}\right) V
# $$
# $$
# MultiHead(Q, K, V) = Concat\left(head_1, ..., head_h\right) W^O \\
# $$
# $$
# head_i = Attention \left(Q W_i^Q, K W_i^K, V W_i^V\right)
# $$
# $h$ - the number of attention heads - parallel sub-layers for Scaled Dot-Product Attention on a vector of smaller dimension ($d_{k} = d_{q} = d_{v} = d_{model} / h$).
# Explain your thoughts: what the reason of dividing before $softmax$ the elements of $QK^{T}$ by $\sqrt{d_{k}}$\,?
# ($d_k = d_{model} / h$ - dimentionality of vectors-keys, queries and values, $d_{model}$ - dimentionality of inout and output vectors at all layers, $h$ - number of attention heads).
# What problems can arise making training less stable without devision by $\sqrt{d_{k}}$ and working with large $d_{model}$?

# %% [markdown]
# ```
#
# The difference in Top two logits differs by the order of sqrt(d_k) and as the model grows in size this difference can grow larger giving rise to a one hot kind of structure so we divide by this term. The problem with such peaky distributions is unstable gradients which can happen if we don't divide by this term. In case when d_model is large it leads to high varience in logits as the distribution is spreadout and also the gradients are low.
#
# ```

# %% [markdown]
# ###1.2 Complexity

# %% [markdown]
# * Let the input of Transformer be the sequence of $n$ tokens. Before it is processed by MultiHeadAttention layer (MHA) it corresponds to the sequence of vectors $x_{1} \ldots x_{n}$. Output from this layer -- if the sequence of vectors $y_{1} \ldots y_{n}$, vectors can be packed in a matrix $Y$ and be denoted with formula $Y = \mathbf{MHA}(x_{1} \ldots x_{n})$.
# Imagine now that there is a hidden layer of a recurrent neural network that performs a transformation similar to the type of input and output $y_{i} = \mathbf{RecurrentLayer}(x_{1} \ldots x_{i})$.
# Let us introduce the function $path(i,j)$, which denotes the number of applications of various operations on the path of creating a vector $y_{j}$ from a sequence $x_{i} \ldots x_{j}$. In terms of O-big $O(\cdot)$, dependent from  $n$ describe, what equals $path(1,n)$ for recurrent layer and  MultiHeadAttention layer.
# e.x. $O(n\log(n)),O(n^{2}),O(1)$

# %% [markdown]
# ```
#
# RecurrentLayer: path(1,n) = O(n)
# MultiHeadAttention: path(1,n) = O(n^2)
#
# ```

# %% [markdown]
# ###1.3 Mask

# %% [markdown]
# The mask is applied to the weights of MultiHeadAttention in transformer before computing the weighted sum of value-vectors. Describe what types of masks are usually used.

# %% [markdown]
# ```
#
# Masks are used to remove redundancy between heads. Typical types of masks used are:
# Rare words (RareW)
# Separator (Seprat)
# Dependency syntax (DepSyn)
# Major syntactic relations (MajRel)
# Relative Position (RelPos)
#
# ```

# %% [markdown]
# ### 1.4 Positional encoding

# %% [markdown]
# As you remember, Transformer treats an input sequence of elements as a time series. Since the Encoder inside the Transformer simultaneously processes the entire input sequence, the information about the position of the element needs to be encoded inside its embedding, since it is not identified in any other way inside the model. That is why the PositionalEncoding layer is used, which sums embeddings with a vector of the same dimension.
# Let the matrix of these vectors for each position of the time series be denoted as $PE$. Then the elements of the matrix are:
#
# $$ PE_{(pos,2i)} = \sin{(pos/10000^{2i/d_{model}})}$$
# $$ PE_{(pos,2i+1)} = \cos{(pos/10000^{2i/d_{model}})}$$
#
# where $pos$ - is the position, $i$ - index of the component of the corresponging vector, $d_{model}$ - dimension of each vector. Thus, even components represent sine values, and odd ones represent cosine values with different arguments.
#
# ***Task:*** propose ANOTHER way of positional encoding. Describe pros and cons of your method comparing to the described above.

# %% [markdown]
# ```
#
# We could represent the positional encoding via binary representation of its pos. so every word has a binary representation and thus our PE will be a matrix in this case.
#
# Pro: Can capture arbitrary length or sequences with a dissimilar representation
# Cons: Discrete values rather than continuous so the representations are not smooth.
# The translation property if sin and cosine function is lost
#
# ```

# %% [markdown]
# ##2. Practical part

# %% [markdown]
# ###2.1 Basic algorithm

# %% [markdown]
# In the  https://github.com/skoltech-nlp/filimdb_evaluation  there is a dataset and the baseline -- translit\_baseline.py. The basic algorithm is based on the following idea: for transliteration, alphabetic n-grams from one language can be transformed into another language into n-grams of the same size, using the most frequent transformation rule found according to statistics on the training sample. To test the implementation, clone the repository, unzip the datasets, and run the evaluation script. To do this, you need to run the following commands:
# * `git clone https://github.com/skoltech-nlp/filimdb_evaluation.git`
# * `cd filimdb_evaluation`
# * `./init.sh translit`
# * `python evaluate_translit.py`

# %%
# !git clone https://github.com/skoltech-nlp/filimdb_evaluation.git
# Out:
# Cloning into 'filimdb_evaluation'...
# remote: Enumerating objects: 540, done.
# remote: Total 540 (delta 0), reused 0 (delta 0), pack-reused 540
# Receiving objects: 100% (540/540), 121.01 MiB | 26.54 MiB/s, done.
# Resolving deltas: 100% (293/293), done.

# %%
cd filimdb_evaluation/
# Out:
# /content/filimdb_evaluation

# %%
# !./init.sh translit
# Out:
# TRANSLIT/
# TRANSLIT/dev.tsv
# TRANSLIT/dev_small.tsv
# TRANSLIT/test.tsv
# TRANSLIT/train.tsv
# TRANSLIT/train_small.tsv
# FILIMDB/
# FILIMDB/train.labels
# FILIMDB/train_unlabeled.texts
# FILIMDB/test.texts
# FILIMDB/train.texts
# FILIMDB/dev.labels
# FILIMDB/dev.texts
# FILIMDB/dev-b.labels
# FILIMDB/dev-b.texts
# FILIMDB/test-b.texts
# PTB/ptb.train.txt
# PTB/
# PTB/README
# PTB/ptb.test.txt
# PTB/ptb.valid.txt

# %%
# !python evaluate_translit.py
# Out:
# Training classifier on 105371 examples from train set ...
# Classifier trained in 3.02s
#
# Classifying train set with 105371 examples ...
# train set classified in 24.94s
#
# Classifying dev set with 26342 examples ...
# dev set classified in 6.24s
#
# Classifying train_small set with 2000 examples ...
# train_small set classified in 0.49s
#
# Classifying dev_small set with 2000 examples ...
# dev_small set classified in 0.49s
#
# Classifying test set with 32926 examples ...
# test set classified in 7.72s
# Predictions saved to preds_translit.tsv
#
# Checking saved predictions ...
# train set accuracy@1: 0.33
# dev set accuracy@1: 0.31
# train_small set accuracy@1: 0.34
# dev_small set accuracy@1: 0.32
# no labels for test set

# %% [markdown]
# ###2.2  Transformer-based approach

# %% [markdown]
# To implement your algorithm, use the template code, which needs to be modified.
#
# Files to be used:
# * `translit.py` - the main file where you need to make changes to be uploaded.
# * `test_implementation.py` - file for testing the modules that you will need to implement as part of this task.
# * `translit_utils` - folder with two `.py` files, which implements the logic of working with data and counting metrics.
# First, you need to add some details in the code of the Transformer architecture, implement the methods of the class `LrScheduler`, which is responsible for updating the learning rate during training.
# Next, you need to select the hyperparameters for the model according to the proposed guide.
#
#
# Script `translit.py` contains the following elements:
#
# * architecture of the Transformer as a class inheriting `torch.nn.Module`;
# * algorithm of learning and classification in the form of  functions train and classify. Two these functions are the most important in this script.

# %% [markdown]
# ####2.2.1  Positional Encoding

# %% [markdown]
# As you remember, Transformer treats an input sequence of elements as a time series. Since the Encoder inside the Transformer simultaneously processes the entire input sequence, the information about the position of the element needs to be encoded inside its embedding, since it is not identified in any other way inside the model. That is why the PositionalEncoding layer is used, which sums embeddings with a vector of the same dimension.
# Let the matrix of these vectors for each position of the time series be denoted as $PE$. Then the elements of the matrix are:
#
# $$ PE_{(pos,2i)} = \sin{(pos/10000^{2i/d_{model}})}$$
# $$ PE_{(pos,2i+1)} = \cos{(pos/10000^{2i/d_{model}})}$$
#
# where $pos$ - is the position, $i$ - index of the component of the corresponging vector, $d_{model}$ - dimension of each vector. Thus, even components represent sine values, and odd ones represent cosine values with different arguments.
#
# In this task you are required to implement these formulas inside the class constructor *PositionalEncoding* in the main file ``translit.py``, which you are to upload. To run the test use the following command:
#
# `python test_implementation.py test_positional_encoding`
#
# Make sure that there is no any `AssertionError`!

# %%
# !pip install fire
# Out:
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 6.7 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire) (1.1.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=8adf3a6fef61fb428bad94d03c9209889c185287d6020b78715f83612c4775b9
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# Installing collected packages: fire
# Successfully installed fire-0.4.0

# %%
# !pip install translit
# Out:
# Collecting translit
#   Downloading translit-0.2a1.tar.bz2 (92 kB)
#      |████████████████████████████████| 92 kB 1.3 MB/s
# Collecting pyenchant
#   Downloading pyenchant-3.2.2-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 5.1 MB/s
# Building wheels for collected packages: translit
#   Building wheel for translit (setup.py) ... done
#   Created wheel for translit: filename=translit-0.2a1-py3-none-any.whl size=113735 sha256=17e39fef688f8133f8eea4007549ccfb4116648c3edb44f93279d158c16e86d2
#   Stored in directory: /root/.cache/pip/wheels/67/82/8b/d57e020abdb1e358ce7190fee438f8104411d46566342f4b88
# Successfully built translit
# Installing collected packages: pyenchant, translit
# Successfully installed pyenchant-3.2.2 translit-0.2a1

# %%
# !pip install Levenshtein
# Out:
# Collecting Levenshtein
#   Downloading Levenshtein-0.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (258 kB)
#      |████████████████████████████████| 258 kB 12.9 MB/s
# Collecting rapidfuzz<3.0.0,>=2.0.1
#   Downloading rapidfuzz-2.0.11-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 66.0 MB/s
# Collecting jarowinkler<1.1.0,>=1.0.2
#   Downloading jarowinkler-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103 kB)
#      |████████████████████████████████| 103 kB 83.9 MB/s
# Installing collected packages: jarowinkler, rapidfuzz, Levenshtein
# Successfully installed Levenshtein-0.18.1 jarowinkler-1.0.2 rapidfuzz-2.0.11

# %%
cd tests/
# Out:
# /content/filimdb_evaluation/tests

# %%
cd -
# Out:
# /content/filimdb_evaluation

# %%
# !python test_translit_implementation.py test_positional_encoding
# Out:
# Test is passed!

# %% [markdown]
# ####2.2.2  MultiHeadAttention

# %% [markdown]
# Then you are required to implement `attention` method in the class  `MultiHeadAttention`. The MultiHeadAttention layer takes as input  query vectors, key and value vectors for each step of the sequence of matrices  Q,K,V correspondingly. Each key vector, value vector, and query vector is obtained as a result of linear projection using one of three trained vector parameter matrices from the previous layer. This semantics can be represented in the form of formulas:
# $$
# Attention(Q, K, V)=softmax\left(\frac{Q K^{T}}{\sqrt{d_{k}}}\right) V\\
# $$
#
# $$
# MultiHead(Q, K, V) = Concat\left(head_1, ... , head_h\right) W^O\\
# $$
#
# $$
# head_i=Attention\left(Q W_i^Q, K W_i^K, V W_i^V\right)\\
# $$
# $h$ - the number of attention heads - parallel sub-layers for Scaled Dot-Product Attention on a vector of smaller dimension ($d_{k} = d_{q} = d_{v} = d_{model} / h$).
# The logic of  \texttt{MultiHeadAttention} is presented in the picture (from original  [paper](https://arxiv.org/abs/1706.03762)):
#
# ![](https://lilianweng.github.io/lil-log/assets/images/transformer.png)
#
#
# Inside a method `attention` you are required to create a dropout layer from  MultiHeadAttention class constructor. Dropout layer is to be applied directly on the attention weights - the result of softmax operation. Value of drop probability  can be regulated in the train in the `model_config['dropout']['attention']`.
#
# The correctness of implementation can be checked with
# `test_implementation.py`:
#
# ```
# python test_implementation.py test_multi_head_attention
# ```

# %%
# !python test_translit_implementation.py test_multi_head_attention
# Out:
# Name: query, shape: torch.Size([2, 1, 3, 5])
# Name: key, shape: torch.Size([2, 1, 3, 5])
# Name: value, shape: torch.Size([2, 1, 3, 5])
# Name: mask, shape: torch.Size([2, 1, 3, 3])
# Test is passed!

# %% [markdown]
# ####2.2.3  LrScheduler

# %% [markdown]
# The last thing you have to prepare is the class  `LrScheduler`, which is in charge of  learning rate updating after every step of the optimizer. You are required to fill the class constructor and the method `learning_rate`. The preferable stratagy of updating the learning rate (lr), is the following two stages:
#
# * "warmup" stage - lr linearly increases until the defined value during the fixed number of steps (the proportion of all training steps - the parameter `train_config['warmup\_steps\_part']` in the train function).
# * "decrease" stage - lr linearly decreases until 0 during the left training steps.
#
# `learning_rate()` call should return the value of  lr at this step,  which number is stored at self.step. The class constructor takes not only `warmup_steps_part` but the peak learning rate value `lr_peak` at the end of "warmup" stage and a string name of the strategy of learning rate scheduling. You can test other strategies if you want to with `self.type attribute`.
#
# Correctness check:
#
# ```
# python test_implementation.py test_lr_scheduler
# ```

# %%
# !python test_translit_implementation.py test_lr_scheduler
# Out:
# Test is passed!

# %%
# !python evaluate.py
# Out:
# Loading train set
# pos 7520
# neg 7480
# Loading dev set
# pos 4980
# neg 5020
# Loading test set
# unlabeled 25000
# Loading dev-b set
# pos 994
# neg 1006
# Loading test-b set
# unlabeled 8599
# Loading train_unlabeled set
# unlabeled 50000
#
# Pretraining classifier on 65000 examples
# Classifier pretrained in 0.00s
#
# Training classifier on 15000 examples from train set ...
# Labels counts: {'pos': 7520, 'neg': 7480}
# {'pos': 0.5013333333333333, 'neg': 0.49866666666666665}
# Classifier trained in 0.00s
#
# Classifying train set with 15000 examples ...
# Predicted labels counts:
# {'pos': 7520, 'neg': 7480}
# train set classified in 0.01s
# Number of correct/total predictions: 7624/15000
#
# Classifying dev set with 10000 examples ...
# Predicted labels counts:
# {'pos': 5042, 'neg': 4958}
# dev set classified in 0.00s
# Number of correct/total predictions: 4936/10000
#
# Classifying test set with 25000 examples ...
# Predicted labels counts:
# {'pos': 12493, 'neg': 12507}
# test set classified in 0.01s
# no labels for test set
#
# Classifying dev-b set with 2000 examples ...
# Predicted labels counts:
# {'pos': 984, 'neg': 1016}
# dev-b set classified in 0.00s
# Number of correct/total predictions: 980/2000
#
# Classifying test-b set with 8599 examples ...
# Predicted labels counts:
# {'pos': 4299, 'neg': 4300}
# test-b set classified in 0.00s
# no labels for test-b set
# Predictions saved to preds.tsv
#
# Checking saved predictions ...
# Loading train set labels
# Loading dev set labels
# Loading test set labels
# Loading dev-b set labels
# Loading test-b set labels
# Number of correct/total predictions: 7624/15000
# train set accuracy: 50.83
# Number of correct/total predictions: 4936/10000
# dev set accuracy: 49.36
# no labels for test set
# Number of correct/total predictions: 980/2000
# dev-b set accuracy: 49.00
# no labels for test-b set

# %% [markdown]
# ###2.3  Hyper-parameters choice

# %% [markdown]
# The model is ready. Now we need to find the optimal hyper-parameters.
#
# In the repository in the TRANSLIT directory, in addition to train, there is also a dev samples and reduced versions of train and dev. The quality of models with different hyperparameters should be monitored on dev or on dev_small samples (in order to save time, since generating transliterations is a rather time-consuming process, comparable to one training epoch). Copy the existing code from `translit.py` into a new script and implement the required evaluation code there in the train function.
# To generate predictions, you can use the `generate_predictions` function, to calculate the accuracy@1 metric, you can use the `compute_metrics` function from the `metrics.py script in the translit_utils directory.
#
#
#
# Hyper-parameters are stored in the dictionary `model_config` and `train_config` in train function. The following hyperparameters in `model_config` and `train_config` are suggested to leave unmodified:
#
# * n_layers $=$ 2
# * n_heads $=$ 2
# * hidden_size $=$ 128
# * fc_hidden_size $=$ 256
# * warmup_steps_part $=$ 0.1
# * batch_size $=$ 200
#
#  You can vary the dropout value. The model has 4 types of : ***embedding dropout*** applied on embdeddings before sending to the first layer of  Encoder or Decoder, ***attention*** dropout applied on the attention weights in the MultiHeadAttention layer, ***residual dropout*** applied on the output of each sublayer (MultiHeadAttention or FeedForward) in layers Encoder and Decoder and, finaly, ***relu dropout*** in used in FeedForward layer. For all 4 types it is suggested to test the same value of dropout from the list: 0.1, 0.15, 0.2.
#  Also it is suggested to test several peak levels of learning rate - **lr_peak** : 5e-4, 1e-3, 2e-3.
#
# Note that if you are using a GPU, then training one epoch takes about 1 minute, and up to 1 GB of video memory is required. When using the CPU, the learning speed slows down by about 2 times. If there are problems with insufficient RAM / video memory, reduce the batch size, but in this case the optimal range of learning rate values will change, and it must be determined again. To train a model with  batch_size $=$ 200 , it will take at least 300 epochs to achieve accuracy 0.66 on dev_small dataset.

# %% [markdown]
# *Question: What are the optimal hyperpameters according to your experiments? Add plots or other descriptions here.*
#
# ```
#
# optimal parameters:
# dropout: embedding: 0.15
# attention: 0.2
# residual: 0.15
# relu: 0.1
#
# lr_peak = 5e-4
#
# This combination of dropout rates worked best for me in addition to a lower learning rate of 5e-4. Although the difference was minor as the epochs were low but still significant.
#
# ```

# %%
# !python evaluate_translit.py
# Out:
# Training classifier on 105371 examples from train set ...
# Using GPU device: cuda
#
# ----------------------------------------
# Epoch: 1
# Run training...
# 527it [00:17, 30.55it/s]
# ** End of epoch, accumulated average loss = 5.318960 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 2
# Run training...
# 527it [00:17, 30.81it/s]
# ** End of epoch, accumulated average loss = 4.022481 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 3
# Run training...
# 527it [00:17, 30.71it/s]
# ** End of epoch, accumulated average loss = 3.387343 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 4
# Run training...
# 527it [00:17, 30.23it/s]
# ** End of epoch, accumulated average loss = 3.026435 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 5
# Run training...
# 527it [00:17, 30.73it/s]
# ** End of epoch, accumulated average loss = 2.902632 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 6
# Run training...
# 527it [00:17, 30.62it/s]
# ** End of epoch, accumulated average loss = 2.712046 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 7
# Run training...
# 527it [00:17, 30.84it/s]
# ** End of epoch, accumulated average loss = 2.273313 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 8
# Run training...
# 527it [00:17, 30.88it/s]
# ** End of epoch, accumulated average loss = 1.699723 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 9
# Run training...
# 527it [00:17, 30.65it/s]
# ** End of epoch, accumulated average loss = 1.394862 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 10
# Run training...
# 527it [00:17, 30.65it/s]
# ** End of epoch, accumulated average loss = 1.240471 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 11
# Run training...
# 527it [00:17, 30.71it/s]
# ** End of epoch, accumulated average loss = 1.130153 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 12
# Run training...
# 527it [00:17, 30.54it/s]
# ** End of epoch, accumulated average loss = 1.045082 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 13
# Run training...
# 527it [00:17, 30.76it/s]
# ** End of epoch, accumulated average loss = 0.972311 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 14
# Run training...
# 527it [00:17, 30.31it/s]
# ** End of epoch, accumulated average loss = 0.911276 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 15
# Run training...
# 527it [00:16, 31.31it/s]
# ** End of epoch, accumulated average loss = 0.857448 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 16
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.808983 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 17
# Run training...
# 527it [00:16, 31.08it/s]
# ** End of epoch, accumulated average loss = 0.764199 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 18
# Run training...
# 527it [00:17, 30.93it/s]
# ** End of epoch, accumulated average loss = 0.720738 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 19
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.685503 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 20
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.652813 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 21
# Run training...
# 527it [00:17, 30.81it/s]
# ** End of epoch, accumulated average loss = 0.628092 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 22
# Run training...
# 527it [00:16, 31.48it/s]
# ** End of epoch, accumulated average loss = 0.606518 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 23
# Run training...
# 527it [00:17, 30.49it/s]
# ** End of epoch, accumulated average loss = 0.589451 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 24
# Run training...
# 527it [00:17, 30.36it/s]
# ** End of epoch, accumulated average loss = 0.571418 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 25
# Run training...
# 527it [00:17, 30.80it/s]
# ** End of epoch, accumulated average loss = 0.557644 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 26
# Run training...
# 527it [00:17, 29.69it/s]
# ** End of epoch, accumulated average loss = 0.542411 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 27
# Run training...
# 527it [00:17, 30.19it/s]
# ** End of epoch, accumulated average loss = 0.531126 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 28
# Run training...
# 527it [00:17, 30.54it/s]
# ** End of epoch, accumulated average loss = 0.521977 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 29
# Run training...
# 527it [00:17, 30.42it/s]
# ** End of epoch, accumulated average loss = 0.508283 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 30
# Run training...
# 527it [00:17, 30.93it/s]
# ** End of epoch, accumulated average loss = 0.498818 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 31
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.489297 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 32
# Run training...
# 527it [00:17, 30.37it/s]
# ** End of epoch, accumulated average loss = 0.479360 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 33
# Run training...
# 527it [00:17, 30.66it/s]
# ** End of epoch, accumulated average loss = 0.471450 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 34
# Run training...
# 527it [00:17, 30.61it/s]
# ** End of epoch, accumulated average loss = 0.461610 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 35
# Run training...
# 527it [00:17, 30.32it/s]
# ** End of epoch, accumulated average loss = 0.453497 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 36
# Run training...
# 527it [00:17, 30.61it/s]
# ** End of epoch, accumulated average loss = 0.447202 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 37
# Run training...
# 527it [00:17, 30.18it/s]
# ** End of epoch, accumulated average loss = 0.438634 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 38
# Run training...
# 527it [00:17, 30.89it/s]
# ** End of epoch, accumulated average loss = 0.433392 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 39
# Run training...
# 527it [00:16, 31.01it/s]
# ** End of epoch, accumulated average loss = 0.428300 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 40
# Run training...
# 527it [00:17, 29.95it/s]
# ** End of epoch, accumulated average loss = 0.422248 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 41
# Run training...
# 527it [00:17, 29.85it/s]
# ** End of epoch, accumulated average loss = 0.417529 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 42
# Run training...
# 527it [00:17, 30.14it/s]
# ** End of epoch, accumulated average loss = 0.413361 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 43
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.409047 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 44
# Run training...
# 527it [00:17, 30.38it/s]
# ** End of epoch, accumulated average loss = 0.405860 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 45
# Run training...
# 527it [00:17, 29.44it/s]
# ** End of epoch, accumulated average loss = 0.401575 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 46
# Run training...
# 527it [00:17, 30.57it/s]
# ** End of epoch, accumulated average loss = 0.398045 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 47
# Run training...
# 527it [00:17, 30.77it/s]
# ** End of epoch, accumulated average loss = 0.394352 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 48
# Run training...
# 527it [00:17, 30.73it/s]
# ** End of epoch, accumulated average loss = 0.391228 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 49
# Run training...
# 527it [00:17, 30.62it/s]
# ** End of epoch, accumulated average loss = 0.388180 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 50
# Run training...
# 527it [00:17, 30.41it/s]
# ** End of epoch, accumulated average loss = 0.385631 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 51
# Run training...
# 527it [00:17, 30.14it/s]
# ** End of epoch, accumulated average loss = 0.382356 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 52
# Run training...
# 527it [00:17, 30.40it/s]
# ** End of epoch, accumulated average loss = 0.379916 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 53
# Run training...
# 527it [00:17, 30.77it/s]
# ** End of epoch, accumulated average loss = 0.378802 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 54
# Run training...
# 527it [00:17, 30.44it/s]
# ** End of epoch, accumulated average loss = 0.375187 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 55
# Run training...
# 527it [00:17, 30.68it/s]
# ** End of epoch, accumulated average loss = 0.373230 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 56
# Run training...
# 527it [00:17, 30.76it/s]
# ** End of epoch, accumulated average loss = 0.371478 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 57
# Run training...
# 527it [00:17, 30.91it/s]
# ** End of epoch, accumulated average loss = 0.368777 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 58
# Run training...
# 527it [00:17, 30.68it/s]
# ** End of epoch, accumulated average loss = 0.367067 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 59
# Run training...
# 527it [00:17, 30.12it/s]
# ** End of epoch, accumulated average loss = 0.364816 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 60
# Run training...
# 527it [00:17, 30.65it/s]
# ** End of epoch, accumulated average loss = 0.362277 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 61
# Run training...
# 527it [00:17, 30.82it/s]
# ** End of epoch, accumulated average loss = 0.361021 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 62
# Run training...
# 527it [00:17, 30.66it/s]
# ** End of epoch, accumulated average loss = 0.359001 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 63
# Run training...
# 527it [00:17, 30.39it/s]
# ** End of epoch, accumulated average loss = 0.357079 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 64
# Run training...
# 527it [00:17, 30.67it/s]
# ** End of epoch, accumulated average loss = 0.355140 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 65
# Run training...
# 527it [00:17, 30.59it/s]
# ** End of epoch, accumulated average loss = 0.352974 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 66
# Run training...
# 527it [00:17, 30.64it/s]
# ** End of epoch, accumulated average loss = 0.352055 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 67
# Run training...
# 527it [00:16, 31.16it/s]
# ** End of epoch, accumulated average loss = 0.348590 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 68
# Run training...
# 527it [00:17, 30.44it/s]
# ** End of epoch, accumulated average loss = 0.346813 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 69
# Run training...
# 527it [00:17, 30.68it/s]
# ** End of epoch, accumulated average loss = 0.346694 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 70
# Run training...
# 527it [00:17, 30.33it/s]
# ** End of epoch, accumulated average loss = 0.345837 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 71
# Run training...
# 527it [00:17, 30.54it/s]
# ** End of epoch, accumulated average loss = 0.343644 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 72
# Run training...
# 527it [00:17, 30.84it/s]
# ** End of epoch, accumulated average loss = 0.342463 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 73
# Run training...
# 527it [00:17, 30.36it/s]
# ** End of epoch, accumulated average loss = 0.341324 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 74
# Run training...
# 527it [00:17, 30.82it/s]
# ** End of epoch, accumulated average loss = 0.339898 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 75
# Run training...
# 527it [00:17, 30.95it/s]
# ** End of epoch, accumulated average loss = 0.338034 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 76
# Run training...
# 527it [00:17, 30.63it/s]
# ** End of epoch, accumulated average loss = 0.337482 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 77
# Run training...
# 527it [00:17, 30.79it/s]
# ** End of epoch, accumulated average loss = 0.336106 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 78
# Run training...
# 527it [00:16, 31.04it/s]
# ** End of epoch, accumulated average loss = 0.335163 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 79
# Run training...
# 527it [00:17, 30.88it/s]
# ** End of epoch, accumulated average loss = 0.334140 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 80
# Run training...
# 527it [00:16, 31.06it/s]
# ** End of epoch, accumulated average loss = 0.332473 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 81
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.330899 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 82
# Run training...
# 527it [00:17, 30.79it/s]
# ** End of epoch, accumulated average loss = 0.329514 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 83
# Run training...
# 527it [00:16, 31.03it/s]
# ** End of epoch, accumulated average loss = 0.328990 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 84
# Run training...
# 527it [00:17, 30.38it/s]
# ** End of epoch, accumulated average loss = 0.328381 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 85
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.327607 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 86
# Run training...
# 527it [00:17, 30.83it/s]
# ** End of epoch, accumulated average loss = 0.327568 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 87
# Run training...
# 527it [00:17, 30.53it/s]
# ** End of epoch, accumulated average loss = 0.326531 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 88
# Run training...
# 527it [00:17, 30.72it/s]
# ** End of epoch, accumulated average loss = 0.324699 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 89
# Run training...
# 527it [00:16, 31.07it/s]
# ** End of epoch, accumulated average loss = 0.325068 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 90
# Run training...
# 527it [00:16, 31.27it/s]
# ** End of epoch, accumulated average loss = 0.323257 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 91
# Run training...
# 527it [00:16, 31.03it/s]
# ** End of epoch, accumulated average loss = 0.322151 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 92
# Run training...
# 527it [00:16, 31.43it/s]
# ** End of epoch, accumulated average loss = 0.322218 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 93
# Run training...
# 527it [00:16, 31.04it/s]
# ** End of epoch, accumulated average loss = 0.321416 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 94
# Run training...
# 527it [00:17, 30.43it/s]
# ** End of epoch, accumulated average loss = 0.320024 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 95
# Run training...
# 527it [00:17, 29.91it/s]
# ** End of epoch, accumulated average loss = 0.319782 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 96
# Run training...
# 527it [00:17, 30.59it/s]
# ** End of epoch, accumulated average loss = 0.318682 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 97
# Run training...
# 527it [00:17, 30.39it/s]
# ** End of epoch, accumulated average loss = 0.318357 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 98
# Run training...
# 527it [00:17, 30.41it/s]
# ** End of epoch, accumulated average loss = 0.317561 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 99
# Run training...
# 527it [00:17, 30.91it/s]
# ** End of epoch, accumulated average loss = 0.316681 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 100
# Run training...
# 527it [00:17, 30.66it/s]
# ** End of epoch, accumulated average loss = 0.316854 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 101
# Run training...
# 527it [00:17, 30.59it/s]
# ** End of epoch, accumulated average loss = 0.315280 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 102
# Run training...
# 527it [00:17, 30.38it/s]
# ** End of epoch, accumulated average loss = 0.315413 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 103
# Run training...
# 527it [00:17, 30.57it/s]
# ** End of epoch, accumulated average loss = 0.314633 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 104
# Run training...
# 527it [00:17, 30.85it/s]
# ** End of epoch, accumulated average loss = 0.314514 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 105
# Run training...
# 527it [00:17, 30.77it/s]
# ** End of epoch, accumulated average loss = 0.313518 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 106
# Run training...
# 527it [00:17, 30.16it/s]
# ** End of epoch, accumulated average loss = 0.312829 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 107
# Run training...
# 527it [00:17, 30.28it/s]
# ** End of epoch, accumulated average loss = 0.311904 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 108
# Run training...
# 527it [00:17, 30.49it/s]
# ** End of epoch, accumulated average loss = 0.311754 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 109
# Run training...
# 527it [00:17, 30.89it/s]
# ** End of epoch, accumulated average loss = 0.311624 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 110
# Run training...
# 527it [00:17, 30.41it/s]
# ** End of epoch, accumulated average loss = 0.310200 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 111
# Run training...
# 527it [00:17, 30.19it/s]
# ** End of epoch, accumulated average loss = 0.310242 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 112
# Run training...
# 527it [00:17, 30.55it/s]
# ** End of epoch, accumulated average loss = 0.309905 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 113
# Run training...
# 527it [00:17, 30.68it/s]
# ** End of epoch, accumulated average loss = 0.309392 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 114
# Run training...
# 527it [00:16, 31.01it/s]
# ** End of epoch, accumulated average loss = 0.308180 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 115
# Run training...
# 527it [00:17, 30.45it/s]
# ** End of epoch, accumulated average loss = 0.307665 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 116
# Run training...
# 527it [00:17, 30.53it/s]
# ** End of epoch, accumulated average loss = 0.307573 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 117
# Run training...
# 527it [00:17, 30.94it/s]
# ** End of epoch, accumulated average loss = 0.306949 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 118
# Run training...
# 527it [00:17, 30.62it/s]
# ** End of epoch, accumulated average loss = 0.306554 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 119
# Run training...
# 527it [00:17, 30.69it/s]
# ** End of epoch, accumulated average loss = 0.306128 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 120
# Run training...
# 527it [00:17, 30.72it/s]
# ** End of epoch, accumulated average loss = 0.305547 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 121
# Run training...
# 527it [00:16, 31.05it/s]
# ** End of epoch, accumulated average loss = 0.305417 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 122
# Run training...
# 527it [00:17, 30.46it/s]
# ** End of epoch, accumulated average loss = 0.304950 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 123
# Run training...
# 527it [00:17, 30.86it/s]
# ** End of epoch, accumulated average loss = 0.304362 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 124
# Run training...
# 527it [00:17, 30.75it/s]
# ** End of epoch, accumulated average loss = 0.304484 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 125
# Run training...
# 527it [00:17, 30.24it/s]
# ** End of epoch, accumulated average loss = 0.303361 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 126
# Run training...
# 527it [00:17, 30.60it/s]
# ** End of epoch, accumulated average loss = 0.302879 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 127
# Run training...
# 527it [00:17, 30.69it/s]
# ** End of epoch, accumulated average loss = 0.303360 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 128
# Run training...
# 527it [00:17, 30.85it/s]
# ** End of epoch, accumulated average loss = 0.302429 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 129
# Run training...
# 527it [00:17, 30.24it/s]
# ** End of epoch, accumulated average loss = 0.301864 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 130
# Run training...
# 527it [00:17, 30.88it/s]
# ** End of epoch, accumulated average loss = 0.301233 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 131
# Run training...
# 527it [00:17, 30.51it/s]
# ** End of epoch, accumulated average loss = 0.300971 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 132
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.300601 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 133
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.300208 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 134
# Run training...
# 527it [00:17, 30.87it/s]
# ** End of epoch, accumulated average loss = 0.299958 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 135
# Run training...
# 527it [00:16, 31.16it/s]
# ** End of epoch, accumulated average loss = 0.299838 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 136
# Run training...
# 527it [00:17, 30.77it/s]
# ** End of epoch, accumulated average loss = 0.299350 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 137
# Run training...
# 527it [00:16, 31.48it/s]
# ** End of epoch, accumulated average loss = 0.298947 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 138
# Run training...
# 527it [00:16, 31.32it/s]
# ** End of epoch, accumulated average loss = 0.298612 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 139
# Run training...
# 527it [00:16, 31.13it/s]
# ** End of epoch, accumulated average loss = 0.297805 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 140
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.297524 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 141
# Run training...
# 527it [00:16, 31.67it/s]
# ** End of epoch, accumulated average loss = 0.297611 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 142
# Run training...
# 527it [00:16, 31.52it/s]
# ** End of epoch, accumulated average loss = 0.297443 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 143
# Run training...
# 527it [00:16, 31.19it/s]
# ** End of epoch, accumulated average loss = 0.297641 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 144
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.296730 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 145
# Run training...
# 527it [00:16, 31.37it/s]
# ** End of epoch, accumulated average loss = 0.295895 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 146
# Run training...
# 527it [00:17, 30.95it/s]
# ** End of epoch, accumulated average loss = 0.295696 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 147
# Run training...
# 527it [00:16, 31.69it/s]
# ** End of epoch, accumulated average loss = 0.296046 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 148
# Run training...
# 527it [00:16, 31.30it/s]
# ** End of epoch, accumulated average loss = 0.295058 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 149
# Run training...
# 527it [00:16, 31.22it/s]
# ** End of epoch, accumulated average loss = 0.295108 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 150
# Run training...
# 527it [00:16, 31.39it/s]
# ** End of epoch, accumulated average loss = 0.294450 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 151
# Run training...
# 527it [00:16, 31.18it/s]
# ** End of epoch, accumulated average loss = 0.293689 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 152
# Run training...
# 527it [00:16, 31.33it/s]
# ** End of epoch, accumulated average loss = 0.294200 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 153
# Run training...
# 527it [00:16, 31.31it/s]
# ** End of epoch, accumulated average loss = 0.293667 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 154
# Run training...
# 527it [00:16, 31.02it/s]
# ** End of epoch, accumulated average loss = 0.292854 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 155
# Run training...
# 527it [00:16, 31.14it/s]
# ** End of epoch, accumulated average loss = 0.292712 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 156
# Run training...
# 527it [00:16, 31.67it/s]
# ** End of epoch, accumulated average loss = 0.292380 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 157
# Run training...
# 527it [00:17, 30.91it/s]
# ** End of epoch, accumulated average loss = 0.292518 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 158
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.292977 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 159
# Run training...
# 527it [00:16, 31.51it/s]
# ** End of epoch, accumulated average loss = 0.291900 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 160
# Run training...
# 527it [00:16, 31.41it/s]
# ** End of epoch, accumulated average loss = 0.291209 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 161
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 0.291047 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 162
# Run training...
# 527it [00:17, 30.88it/s]
# ** End of epoch, accumulated average loss = 0.291419 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 163
# Run training...
# 527it [00:17, 30.87it/s]
# ** End of epoch, accumulated average loss = 0.291205 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 164
# Run training...
# 527it [00:17, 30.51it/s]
# ** End of epoch, accumulated average loss = 0.291446 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 165
# Run training...
# 527it [00:17, 30.54it/s]
# ** End of epoch, accumulated average loss = 0.289411 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 166
# Run training...
# 527it [00:17, 30.43it/s]
# ** End of epoch, accumulated average loss = 0.289517 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 167
# Run training...
# 527it [00:17, 30.52it/s]
# ** End of epoch, accumulated average loss = 0.290096 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 168
# Run training...
# 527it [00:17, 30.69it/s]
# ** End of epoch, accumulated average loss = 0.288629 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 169
# Run training...
# 527it [00:16, 31.01it/s]
# ** End of epoch, accumulated average loss = 0.289483 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 170
# Run training...
# 527it [00:16, 31.25it/s]
# ** End of epoch, accumulated average loss = 0.288876 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 171
# Run training...
# 527it [00:16, 31.15it/s]
# ** End of epoch, accumulated average loss = 0.289340 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 172
# Run training...
# 527it [00:17, 30.49it/s]
# ** End of epoch, accumulated average loss = 0.288175 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 173
# Run training...
# 527it [00:17, 30.79it/s]
# ** End of epoch, accumulated average loss = 0.288102 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 174
# Run training...
# 527it [00:16, 31.37it/s]
# ** End of epoch, accumulated average loss = 0.287419 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 175
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.287640 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 176
# Run training...
# 527it [00:16, 31.20it/s]
# ** End of epoch, accumulated average loss = 0.286828 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 177
# Run training...
# 527it [00:16, 31.10it/s]
# ** End of epoch, accumulated average loss = 0.287074 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 178
# Run training...
# 527it [00:16, 31.50it/s]
# ** End of epoch, accumulated average loss = 0.287065 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 179
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 0.285976 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 180
# Run training...
# 527it [00:16, 31.51it/s]
# ** End of epoch, accumulated average loss = 0.286304 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 181
# Run training...
# 527it [00:16, 31.28it/s]
# ** End of epoch, accumulated average loss = 0.286504 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 182
# Run training...
# 527it [00:17, 30.52it/s]
# ** End of epoch, accumulated average loss = 0.286531 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 183
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.285976 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 184
# Run training...
# 527it [00:17, 30.92it/s]
# ** End of epoch, accumulated average loss = 0.285823 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 185
# Run training...
# 527it [00:16, 31.65it/s]
# ** End of epoch, accumulated average loss = 0.286394 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 186
# Run training...
# 527it [00:17, 30.96it/s]
# ** End of epoch, accumulated average loss = 0.285421 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 187
# Run training...
# 527it [00:16, 31.43it/s]
# ** End of epoch, accumulated average loss = 0.285454 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 188
# Run training...
# 527it [00:16, 31.27it/s]
# ** End of epoch, accumulated average loss = 0.285016 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 189
# Run training...
# 527it [00:16, 31.14it/s]
# ** End of epoch, accumulated average loss = 0.284252 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 190
# Run training...
# 527it [00:16, 31.54it/s]
# ** End of epoch, accumulated average loss = 0.284214 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 191
# Run training...
# 527it [00:16, 31.06it/s]
# ** End of epoch, accumulated average loss = 0.283954 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 192
# Run training...
# 527it [00:16, 31.11it/s]
# ** End of epoch, accumulated average loss = 0.283835 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 193
# Run training...
# 527it [00:17, 30.65it/s]
# ** End of epoch, accumulated average loss = 0.283695 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 194
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.283794 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 195
# Run training...
# 527it [00:16, 31.49it/s]
# ** End of epoch, accumulated average loss = 0.283514 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 196
# Run training...
# 527it [00:17, 30.83it/s]
# ** End of epoch, accumulated average loss = 0.283197 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 197
# Run training...
# 527it [00:16, 31.22it/s]
# ** End of epoch, accumulated average loss = 0.282620 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 198
# Run training...
# 527it [00:16, 31.27it/s]
# ** End of epoch, accumulated average loss = 0.282389 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 199
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.281905 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 200
# Run training...
# 527it [00:16, 31.08it/s]
# ** End of epoch, accumulated average loss = 0.281967 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 201
# Run training...
# 527it [00:17, 30.96it/s]
# ** End of epoch, accumulated average loss = 0.282536 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 202
# Run training...
# 527it [00:16, 31.25it/s]
# ** End of epoch, accumulated average loss = 0.281375 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 203
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.281567 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 204
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.281268 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 205
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.281592 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 206
# Run training...
# 527it [00:16, 31.13it/s]
# ** End of epoch, accumulated average loss = 0.280885 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 207
# Run training...
# 527it [00:17, 30.74it/s]
# ** End of epoch, accumulated average loss = 0.280993 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 208
# Run training...
# 527it [00:16, 31.21it/s]
# ** End of epoch, accumulated average loss = 0.280371 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 209
# Run training...
# 527it [00:16, 32.52it/s]
# ** End of epoch, accumulated average loss = 0.280637 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 210
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.280328 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 211
# Run training...
# 527it [00:16, 31.60it/s]
# ** End of epoch, accumulated average loss = 0.280262 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 212
# Run training...
# 527it [00:16, 31.92it/s]
# ** End of epoch, accumulated average loss = 0.280653 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 213
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.280558 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 214
# Run training...
# 527it [00:16, 32.00it/s]
# ** End of epoch, accumulated average loss = 0.279641 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 215
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.279204 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 216
# Run training...
# 527it [00:16, 31.18it/s]
# ** End of epoch, accumulated average loss = 0.279259 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 217
# Run training...
# 527it [00:16, 31.09it/s]
# ** End of epoch, accumulated average loss = 0.279175 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 218
# Run training...
# 527it [00:16, 31.47it/s]
# ** End of epoch, accumulated average loss = 0.278421 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 219
# Run training...
# 527it [00:16, 31.71it/s]
# ** End of epoch, accumulated average loss = 0.278656 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 220
# Run training...
# 527it [00:16, 31.88it/s]
# ** End of epoch, accumulated average loss = 0.279024 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 221
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.278601 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 222
# Run training...
# 527it [00:16, 31.94it/s]
# ** End of epoch, accumulated average loss = 0.278263 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 223
# Run training...
# 527it [00:16, 32.60it/s]
# ** End of epoch, accumulated average loss = 0.278368 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 224
# Run training...
# 527it [00:16, 31.97it/s]
# ** End of epoch, accumulated average loss = 0.278339 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 225
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.277080 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 226
# Run training...
# 527it [00:16, 31.67it/s]
# ** End of epoch, accumulated average loss = 0.277472 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 227
# Run training...
# 527it [00:16, 31.39it/s]
# ** End of epoch, accumulated average loss = 0.277324 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 228
# Run training...
# 527it [00:16, 31.03it/s]
# ** End of epoch, accumulated average loss = 0.277269 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 229
# Run training...
# 527it [00:17, 30.92it/s]
# ** End of epoch, accumulated average loss = 0.277241 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 230
# Run training...
# 527it [00:16, 31.23it/s]
# ** End of epoch, accumulated average loss = 0.276014 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 231
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.276441 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 232
# Run training...
# 527it [00:16, 31.54it/s]
# ** End of epoch, accumulated average loss = 0.276545 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 233
# Run training...
# 527it [00:16, 31.85it/s]
# ** End of epoch, accumulated average loss = 0.277579 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 234
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.275870 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 235
# Run training...
# 527it [00:17, 30.88it/s]
# ** End of epoch, accumulated average loss = 0.276288 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 236
# Run training...
# 527it [00:16, 31.24it/s]
# ** End of epoch, accumulated average loss = 0.275705 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 237
# Run training...
# 527it [00:17, 30.90it/s]
# ** End of epoch, accumulated average loss = 0.275507 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 238
# Run training...
# 527it [00:16, 31.41it/s]
# ** End of epoch, accumulated average loss = 0.275637 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 239
# Run training...
# 527it [00:17, 30.92it/s]
# ** End of epoch, accumulated average loss = 0.275288 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 240
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.275098 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 241
# Run training...
# 527it [00:16, 31.31it/s]
# ** End of epoch, accumulated average loss = 0.275043 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 242
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.275073 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 243
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 0.275151 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 244
# Run training...
# 527it [00:16, 31.04it/s]
# ** End of epoch, accumulated average loss = 0.274485 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 245
# Run training...
# 527it [00:16, 31.02it/s]
# ** End of epoch, accumulated average loss = 0.274062 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 246
# Run training...
# 527it [00:16, 31.00it/s]
# ** End of epoch, accumulated average loss = 0.274121 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 247
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.273856 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 248
# Run training...
# 527it [00:17, 30.86it/s]
# ** End of epoch, accumulated average loss = 0.274151 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 249
# Run training...
# 527it [00:17, 30.90it/s]
# ** End of epoch, accumulated average loss = 0.274239 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 250
# Run training...
# 527it [00:17, 30.81it/s]
# ** End of epoch, accumulated average loss = 0.274110 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 251
# Run training...
# 527it [00:16, 31.63it/s]
# ** End of epoch, accumulated average loss = 0.272928 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 252
# Run training...
# 527it [00:16, 31.25it/s]
# ** End of epoch, accumulated average loss = 0.274341 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 253
# Run training...
# 527it [00:17, 30.93it/s]
# ** End of epoch, accumulated average loss = 0.273931 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 254
# Run training...
# 527it [00:16, 31.40it/s]
# ** End of epoch, accumulated average loss = 0.273868 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 255
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.273267 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 256
# Run training...
# 527it [00:17, 30.73it/s]
# ** End of epoch, accumulated average loss = 0.272458 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 257
# Run training...
# 527it [00:16, 31.72it/s]
# ** End of epoch, accumulated average loss = 0.272631 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 258
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.272668 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 259
# Run training...
# 527it [00:17, 30.38it/s]
# ** End of epoch, accumulated average loss = 0.272239 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 260
# Run training...
# 527it [00:16, 31.50it/s]
# ** End of epoch, accumulated average loss = 0.271743 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 261
# Run training...
# 527it [00:16, 31.73it/s]
# ** End of epoch, accumulated average loss = 0.272896 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 262
# Run training...
# 527it [00:16, 31.02it/s]
# ** End of epoch, accumulated average loss = 0.272545 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 263
# Run training...
# 527it [00:17, 30.51it/s]
# ** End of epoch, accumulated average loss = 0.271592 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 264
# Run training...
# 527it [00:16, 31.12it/s]
# ** End of epoch, accumulated average loss = 0.271092 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 265
# Run training...
# 527it [00:17, 30.74it/s]
# ** End of epoch, accumulated average loss = 0.271551 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 266
# Run training...
# 527it [00:16, 32.23it/s]
# ** End of epoch, accumulated average loss = 0.271902 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 267
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.272108 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 268
# Run training...
# 527it [00:16, 31.64it/s]
# ** End of epoch, accumulated average loss = 0.272288 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 269
# Run training...
# 527it [00:16, 31.69it/s]
# ** End of epoch, accumulated average loss = 0.271636 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 270
# Run training...
# 527it [00:16, 31.63it/s]
# ** End of epoch, accumulated average loss = 0.270981 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 271
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.271331 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 272
# ...
#
# ----------------------------------------
# Epoch: 516
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.247323 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 517
# Run training...
# 527it [00:17, 30.38it/s]
# ** End of epoch, accumulated average loss = 0.248000 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 518
# Run training...
# 527it [00:16, 31.31it/s]
# ** End of epoch, accumulated average loss = 0.248097 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 519
# Run training...
# 527it [00:16, 31.32it/s]
# ** End of epoch, accumulated average loss = 0.247868 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 520
# Run training...
# 527it [00:17, 30.75it/s]
# ** End of epoch, accumulated average loss = 0.247198 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 521
# Run training...
# 527it [00:16, 31.44it/s]
# ** End of epoch, accumulated average loss = 0.247419 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 522
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.247895 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 523
# Run training...
# 527it [00:16, 31.11it/s]
# ** End of epoch, accumulated average loss = 0.247432 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 524
# Run training...
# 527it [00:16, 31.40it/s]
# ** End of epoch, accumulated average loss = 0.247290 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 525
# Run training...
# 527it [00:17, 30.70it/s]
# ** End of epoch, accumulated average loss = 0.247164 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 526
# Run training...
# 527it [00:16, 31.51it/s]
# ** End of epoch, accumulated average loss = 0.247797 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 527
# Run training...
# 527it [00:16, 31.25it/s]
# ** End of epoch, accumulated average loss = 0.247703 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 528
# Run training...
# 527it [00:16, 32.25it/s]
# ** End of epoch, accumulated average loss = 0.247038 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 529
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.247287 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 530
# Run training...
# 527it [00:17, 30.65it/s]
# ** End of epoch, accumulated average loss = 0.246467 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 531
# Run training...
# 527it [00:16, 31.41it/s]
# ** End of epoch, accumulated average loss = 0.246843 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 532
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.246412 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 533
# Run training...
# 527it [00:16, 31.64it/s]
# ** End of epoch, accumulated average loss = 0.246817 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 534
# Run training...
# 527it [00:16, 31.15it/s]
# ** End of epoch, accumulated average loss = 0.246117 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 535
# Run training...
# 527it [00:16, 31.48it/s]
# ** End of epoch, accumulated average loss = 0.246790 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 536
# Run training...
# 527it [00:16, 31.61it/s]
# ** End of epoch, accumulated average loss = 0.246650 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 537
# Run training...
# 527it [00:17, 30.97it/s]
# ** End of epoch, accumulated average loss = 0.246647 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 538
# Run training...
# 527it [00:16, 31.40it/s]
# ** End of epoch, accumulated average loss = 0.245984 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 539
# Run training...
# 527it [00:16, 31.61it/s]
# ** End of epoch, accumulated average loss = 0.246188 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 540
# Run training...
# 527it [00:16, 31.17it/s]
# ** End of epoch, accumulated average loss = 0.247025 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 541
# Run training...
# 527it [00:17, 30.80it/s]
# ** End of epoch, accumulated average loss = 0.246524 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 542
# Run training...
# 527it [00:16, 31.51it/s]
# ** End of epoch, accumulated average loss = 0.246011 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 543
# Run training...
# 527it [00:16, 31.41it/s]
# ** End of epoch, accumulated average loss = 0.246735 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 544
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.246040 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 545
# Run training...
# 527it [00:17, 30.83it/s]
# ** End of epoch, accumulated average loss = 0.245970 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 546
# Run training...
# 527it [00:16, 31.35it/s]
# ** End of epoch, accumulated average loss = 0.245959 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 547
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.245869 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 548
# Run training...
# 527it [00:16, 31.27it/s]
# ** End of epoch, accumulated average loss = 0.245492 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 549
# Run training...
# 527it [00:16, 31.11it/s]
# ** End of epoch, accumulated average loss = 0.245669 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 550
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.245777 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 551
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.246136 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 552
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.244953 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 553
# Run training...
# 527it [00:16, 31.87it/s]
# ** End of epoch, accumulated average loss = 0.245544 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 554
# Run training...
# 527it [00:16, 31.93it/s]
# ** End of epoch, accumulated average loss = 0.245587 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 555
# Run training...
# 527it [00:17, 30.87it/s]
# ** End of epoch, accumulated average loss = 0.245723 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 556
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 0.245102 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 557
# Run training...
# 527it [00:16, 32.29it/s]
# ** End of epoch, accumulated average loss = 0.244824 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 558
# Run training...
# 527it [00:16, 31.01it/s]
# ** End of epoch, accumulated average loss = 0.245589 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 559
# Run training...
# 527it [00:16, 31.37it/s]
# ** End of epoch, accumulated average loss = 0.245808 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 560
# Run training...
# 527it [00:16, 31.43it/s]
# ** End of epoch, accumulated average loss = 0.244920 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 561
# Run training...
# 527it [00:16, 31.90it/s]
# ** End of epoch, accumulated average loss = 0.245621 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 562
# Run training...
# 527it [00:16, 31.75it/s]
# ** End of epoch, accumulated average loss = 0.244946 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 563
# Run training...
# 527it [00:16, 31.93it/s]
# ** End of epoch, accumulated average loss = 0.245573 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 564
# Run training...
# 527it [00:16, 31.39it/s]
# ** End of epoch, accumulated average loss = 0.245539 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 565
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.243889 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 566
# Run training...
# 527it [00:16, 31.95it/s]
# ** End of epoch, accumulated average loss = 0.244709 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 567
# Run training...
# 527it [00:16, 31.95it/s]
# ** End of epoch, accumulated average loss = 0.245483 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 568
# Run training...
# 527it [00:16, 31.53it/s]
# ** End of epoch, accumulated average loss = 0.244878 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 569
# Run training...
# 527it [00:16, 31.52it/s]
# ** End of epoch, accumulated average loss = 0.244527 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 570
# Run training...
# 527it [00:16, 31.75it/s]
# ** End of epoch, accumulated average loss = 0.244667 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 571
# Run training...
# 527it [00:16, 32.03it/s]
# ** End of epoch, accumulated average loss = 0.244356 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 572
# Run training...
# 527it [00:16, 31.68it/s]
# ** End of epoch, accumulated average loss = 0.243704 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 573
# Run training...
# 527it [00:16, 31.43it/s]
# ** End of epoch, accumulated average loss = 0.244961 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 574
# Run training...
# 527it [00:16, 31.94it/s]
# ** End of epoch, accumulated average loss = 0.244121 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 575
# Run training...
# 527it [00:16, 31.23it/s]
# ** End of epoch, accumulated average loss = 0.244117 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 576
# Run training...
# 527it [00:16, 31.40it/s]
# ** End of epoch, accumulated average loss = 0.243879 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 577
# Run training...
# 527it [00:16, 31.53it/s]
# ** End of epoch, accumulated average loss = 0.243864 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 578
# Run training...
# 527it [00:16, 31.33it/s]
# ** End of epoch, accumulated average loss = 0.244316 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 579
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.243966 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 580
# Run training...
# 527it [00:17, 30.76it/s]
# ** End of epoch, accumulated average loss = 0.245163 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 581
# Run training...
# 527it [00:16, 32.41it/s]
# ** End of epoch, accumulated average loss = 0.244135 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 582
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.243418 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 583
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.243258 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 584
# Run training...
# 527it [00:16, 31.53it/s]
# ** End of epoch, accumulated average loss = 0.244139 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 585
# Run training...
# 527it [00:16, 31.89it/s]
# ** End of epoch, accumulated average loss = 0.242812 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 586
# Run training...
# 527it [00:16, 32.31it/s]
# ** End of epoch, accumulated average loss = 0.243852 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 587
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.243941 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 588
# Run training...
# 527it [00:16, 31.78it/s]
# ** End of epoch, accumulated average loss = 0.243761 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 589
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.243794 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 590
# Run training...
# 527it [00:16, 31.32it/s]
# ** End of epoch, accumulated average loss = 0.243273 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 591
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.243377 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 592
# Run training...
# 527it [00:16, 31.29it/s]
# ** End of epoch, accumulated average loss = 0.243000 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 593
# Run training...
# 527it [00:16, 31.71it/s]
# ** End of epoch, accumulated average loss = 0.242771 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 594
# Run training...
# 527it [00:17, 30.89it/s]
# ** End of epoch, accumulated average loss = 0.244049 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 595
# Run training...
# 527it [00:16, 31.47it/s]
# ** End of epoch, accumulated average loss = 0.243602 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 596
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.242861 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 597
# Run training...
# 527it [00:16, 31.21it/s]
# ** End of epoch, accumulated average loss = 0.243424 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 598
# Run training...
# 527it [00:16, 31.55it/s]
# ** End of epoch, accumulated average loss = 0.243380 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 599
# Run training...
# 527it [00:16, 31.54it/s]
# ** End of epoch, accumulated average loss = 0.243622 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 600
# Run training...
# 527it [00:16, 32.02it/s]
# ** End of epoch, accumulated average loss = 0.242944 **
# ** Elapsed time: 0:00:16**
# Classifier trained in 10111.62s
#
# Classifying train set with 105371 examples ...
# Using GPU device: cuda
# 100% 527/527 [01:21<00:00,  6.49it/s]
# train set classified in 81.28s
#
# Classifying dev set with 26342 examples ...
# Using GPU device: cuda
# 100% 132/132 [00:20<00:00,  6.60it/s]
# dev set classified in 20.01s
#
# Classifying train_small set with 2000 examples ...
# Using GPU device: cuda
# 100% 10/10 [00:01<00:00,  6.38it/s]
# train_small set classified in 1.57s
#
# Classifying dev_small set with 2000 examples ...
# Using GPU device: cuda
# 100% 10/10 [00:01<00:00,  6.49it/s]
# dev_small set classified in 1.54s
#
# Classifying test set with 32926 examples ...
# Using GPU device: cuda
# 100% 165/165 [00:25<00:00,  6.47it/s]
# test set classified in 25.52s
# Predictions saved to preds_translit.tsv
#
# Checking saved predictions ...
# train set accuracy@1: 0.71
# dev set accuracy@1: 0.67
# train_small set accuracy@1: 0.71
# dev_small set accuracy@1: 0.69
# no labels for test set

# %% [markdown]
# ##3. Research part

# %% [markdown]
# We suggest to implement an additional regularization method - **label smoothing**. Now imagine that we have a prediction vector from probabilities at position t in the sequence of tokens for each token id from the vocabulary. CrossEntropy compares it with ground truth one-hot representation
#
# $$[0, ... 0, 1, 0, ..., 0].$$
#
# And now imagine that we are slightly "smoothed" the values in the ground truth vector and obtained
#
# $$[\frac{\alpha}{|V|}, ..., \frac{\alpha}{|V|}, 1(1-\alpha)+\frac{\alpha}{|V|},  \frac{\alpha}{|V|}, ... \frac{\alpha}{|V|}],$$
#
# where $\alpha$ - parameter from 0 to 1, $|V|$ - vocabulary size - number of components in the ground truth vector. The values ​​of this new vector are still summed to 1. Calculate the cross-entropy of our prediction vector and the new ground truth. Now, firstly, cross-entropy will never reach 0, and secondly, the result of the error function will require the model, as usual, to return the highest probability vector compared to other components of the probability vector for the correct token in the dictionary, but at the same time not too large, because as the value of this probability approaches 1, the value of the error function increases. For research on the use of label smoothing, see the [paper](https://arxiv.org/abs/1906.02629).
#
# Accordingly, in order to embed label smoothing into the model, it is necessary to carry out the transformation described above on the ground truth vectors, as well as to implement the cross-entropy calculation, since the used `torch.nn.CrossEntropy` class is not quite suitable, since for the ground truth representation of `__call__` method takes the id of the correct token and builds a one-hot vector already inside. However, it is possible to implement what is required based on the internal implementation of this class [CrossEntropyLoss](https://pytorch.org/docs/stable/_modules/torch/nn/modules/loss.html#CrossEntropyLoss).
#
#
# Test different values of $\alpha$ (e.x, 0.05, 0.1, 0.2). Describe your experiments and results.

# %% [markdown]
# ```
#
# ENTER HERE YOUR ANSWER
#
# ```

# %%
# !python evaluate_translit.py
# Out:
# Training classifier on 105371 examples from train set ...
# Using GPU device: cuda
#
# ----------------------------------------
# Epoch: 1
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 5.389215 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 2
# Run training...
# 527it [00:16, 31.92it/s]
# ** End of epoch, accumulated average loss = 3.976820 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 3
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 3.441568 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 4
# Run training...
# 527it [00:17, 30.90it/s]
# ** End of epoch, accumulated average loss = 3.098935 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 5
# Run training...
# 527it [00:16, 32.30it/s]
# ** End of epoch, accumulated average loss = 2.943254 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 6
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 2.833234 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 7
# Run training...
# 527it [00:16, 31.90it/s]
# ** End of epoch, accumulated average loss = 2.514953 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 8
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 1.878395 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 9
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 1.467802 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 10
# Run training...
# 527it [00:16, 31.88it/s]
# ** End of epoch, accumulated average loss = 1.275400 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 11
# Run training...
# 527it [00:16, 32.02it/s]
# ** End of epoch, accumulated average loss = 1.153076 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 12
# Run training...
# 527it [00:15, 33.27it/s]
# ** End of epoch, accumulated average loss = 1.061843 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 13
# Run training...
# 527it [00:16, 32.54it/s]
# ** End of epoch, accumulated average loss = 0.983513 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 14
# Run training...
# 527it [00:16, 32.59it/s]
# ** End of epoch, accumulated average loss = 0.920110 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 15
# Run training...
# 527it [00:16, 32.23it/s]
# ** End of epoch, accumulated average loss = 0.865045 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 16
# Run training...
# 527it [00:16, 31.81it/s]
# ** End of epoch, accumulated average loss = 0.815036 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 17
# Run training...
# 527it [00:16, 32.54it/s]
# ** End of epoch, accumulated average loss = 0.773912 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 18
# Run training...
# 527it [00:16, 31.72it/s]
# ** End of epoch, accumulated average loss = 0.736519 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 19
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.707060 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 20
# Run training...
# 527it [00:16, 32.27it/s]
# ** End of epoch, accumulated average loss = 0.675081 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 21
# Run training...
# 527it [00:17, 30.89it/s]
# ** End of epoch, accumulated average loss = 0.645063 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 22
# Run training...
# 527it [00:16, 32.72it/s]
# ** End of epoch, accumulated average loss = 0.617210 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 23
# Run training...
# 527it [00:16, 32.11it/s]
# ** End of epoch, accumulated average loss = 0.596530 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 24
# Run training...
# 527it [00:16, 32.44it/s]
# ** End of epoch, accumulated average loss = 0.578911 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 25
# Run training...
# 527it [00:16, 32.29it/s]
# ** End of epoch, accumulated average loss = 0.561877 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 26
# Run training...
# 527it [00:16, 32.07it/s]
# ** End of epoch, accumulated average loss = 0.547712 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 27
# Run training...
# 527it [00:16, 32.45it/s]
# ** End of epoch, accumulated average loss = 0.533562 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 28
# Run training...
# 527it [00:16, 32.02it/s]
# ** End of epoch, accumulated average loss = 0.523020 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 29
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.509994 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 30
# Run training...
# 527it [00:16, 32.04it/s]
# ** End of epoch, accumulated average loss = 0.500271 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 31
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.488129 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 32
# Run training...
# 527it [00:16, 32.67it/s]
# ** End of epoch, accumulated average loss = 0.478698 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 33
# Run training...
# 527it [00:16, 31.45it/s]
# ** End of epoch, accumulated average loss = 0.470453 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 34
# Run training...
# 527it [00:16, 32.24it/s]
# ** End of epoch, accumulated average loss = 0.460483 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 35
# Run training...
# 527it [00:16, 31.91it/s]
# ** End of epoch, accumulated average loss = 0.453398 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 36
# Run training...
# 527it [00:16, 32.28it/s]
# ** End of epoch, accumulated average loss = 0.444726 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 37
# Run training...
# 527it [00:16, 32.40it/s]
# ** End of epoch, accumulated average loss = 0.439153 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 38
# Run training...
# 527it [00:16, 32.42it/s]
# ** End of epoch, accumulated average loss = 0.432434 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 39
# Run training...
# 527it [00:16, 31.87it/s]
# ** End of epoch, accumulated average loss = 0.428333 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 40
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.422514 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 41
# Run training...
# 527it [00:16, 31.93it/s]
# ** End of epoch, accumulated average loss = 0.417277 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 42
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.411906 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 43
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.410549 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 44
# Run training...
# 527it [00:16, 32.31it/s]
# ** End of epoch, accumulated average loss = 0.405348 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 45
# Run training...
# 527it [00:16, 31.51it/s]
# ** End of epoch, accumulated average loss = 0.401292 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 46
# Run training...
# 527it [00:16, 31.81it/s]
# ** End of epoch, accumulated average loss = 0.397610 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 47
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.394739 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 48
# Run training...
# 527it [00:16, 31.48it/s]
# ** End of epoch, accumulated average loss = 0.390627 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 49
# Run training...
# 527it [00:16, 31.15it/s]
# ** End of epoch, accumulated average loss = 0.388678 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 50
# Run training...
# 527it [00:16, 31.39it/s]
# ** End of epoch, accumulated average loss = 0.385127 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 51
# Run training...
# 527it [00:16, 31.93it/s]
# ** End of epoch, accumulated average loss = 0.382432 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 52
# Run training...
# 527it [00:16, 32.14it/s]
# ** End of epoch, accumulated average loss = 0.380513 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 53
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.377624 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 54
# Run training...
# 527it [00:16, 31.58it/s]
# ** End of epoch, accumulated average loss = 0.375491 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 55
# Run training...
# 527it [00:16, 31.94it/s]
# ** End of epoch, accumulated average loss = 0.372751 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 56
# Run training...
# 527it [00:16, 32.73it/s]
# ** End of epoch, accumulated average loss = 0.371628 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 57
# Run training...
# 527it [00:16, 31.49it/s]
# ** End of epoch, accumulated average loss = 0.368727 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 58
# Run training...
# 527it [00:16, 31.19it/s]
# ** End of epoch, accumulated average loss = 0.367948 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 59
# Run training...
# 527it [00:16, 32.38it/s]
# ** End of epoch, accumulated average loss = 0.364288 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 60
# Run training...
# 527it [00:16, 31.78it/s]
# ** End of epoch, accumulated average loss = 0.363411 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 61
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.361227 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 62
# Run training...
# 527it [00:16, 31.75it/s]
# ** End of epoch, accumulated average loss = 0.359687 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 63
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.357979 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 64
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.355484 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 65
# Run training...
# 527it [00:16, 31.81it/s]
# ** End of epoch, accumulated average loss = 0.353405 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 66
# Run training...
# 527it [00:16, 32.53it/s]
# ** End of epoch, accumulated average loss = 0.351224 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 67
# Run training...
# 527it [00:16, 32.53it/s]
# ** End of epoch, accumulated average loss = 0.349602 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 68
# Run training...
# 527it [00:16, 31.03it/s]
# ** End of epoch, accumulated average loss = 0.348731 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 69
# Run training...
# 527it [00:17, 30.09it/s]
# ** End of epoch, accumulated average loss = 0.345802 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 70
# Run training...
# 527it [00:17, 30.89it/s]
# ** End of epoch, accumulated average loss = 0.344798 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 71
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.343998 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 72
# Run training...
# 527it [00:17, 30.90it/s]
# ** End of epoch, accumulated average loss = 0.342337 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 73
# Run training...
# 527it [00:17, 30.58it/s]
# ** End of epoch, accumulated average loss = 0.340953 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 74
# Run training...
# 527it [00:17, 30.43it/s]
# ** End of epoch, accumulated average loss = 0.339355 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 75
# Run training...
# 527it [00:17, 30.57it/s]
# ** End of epoch, accumulated average loss = 0.337380 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 76
# Run training...
# 527it [00:16, 31.54it/s]
# ** End of epoch, accumulated average loss = 0.337986 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 77
# Run training...
# 527it [00:17, 30.50it/s]
# ** End of epoch, accumulated average loss = 0.335701 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 78
# Run training...
# 527it [00:17, 30.13it/s]
# ** End of epoch, accumulated average loss = 0.335448 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 79
# Run training...
# 527it [00:16, 31.21it/s]
# ** End of epoch, accumulated average loss = 0.333533 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 80
# Run training...
# 527it [00:16, 32.32it/s]
# ** End of epoch, accumulated average loss = 0.331952 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 81
# Run training...
# 527it [00:16, 31.75it/s]
# ** End of epoch, accumulated average loss = 0.331061 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 82
# Run training...
# 527it [00:16, 31.64it/s]
# ** End of epoch, accumulated average loss = 0.331548 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 83
# Run training...
# 527it [00:16, 31.60it/s]
# ** End of epoch, accumulated average loss = 0.329786 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 84
# Run training...
# 527it [00:16, 31.57it/s]
# ** End of epoch, accumulated average loss = 0.329435 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 85
# Run training...
# 527it [00:16, 32.32it/s]
# ** End of epoch, accumulated average loss = 0.326606 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 86
# Run training...
# 527it [00:16, 31.61it/s]
# ** End of epoch, accumulated average loss = 0.326943 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 87
# Run training...
# 527it [00:16, 31.23it/s]
# ** End of epoch, accumulated average loss = 0.325680 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 88
# Run training...
# 527it [00:16, 31.33it/s]
# ** End of epoch, accumulated average loss = 0.324662 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 89
# Run training...
# 527it [00:16, 31.62it/s]
# ** End of epoch, accumulated average loss = 0.324525 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 90
# Run training...
# 527it [00:16, 32.58it/s]
# ** End of epoch, accumulated average loss = 0.322691 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 91
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.321853 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 92
# Run training...
# 527it [00:16, 31.87it/s]
# ** End of epoch, accumulated average loss = 0.321870 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 93
# Run training...
# 527it [00:16, 31.29it/s]
# ** End of epoch, accumulated average loss = 0.322199 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 94
# Run training...
# 527it [00:16, 31.15it/s]
# ** End of epoch, accumulated average loss = 0.319652 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 95
# Run training...
# 527it [00:16, 32.45it/s]
# ** End of epoch, accumulated average loss = 0.319145 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 96
# Run training...
# 527it [00:16, 31.60it/s]
# ** End of epoch, accumulated average loss = 0.319282 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 97
# Run training...
# 527it [00:16, 31.62it/s]
# ** End of epoch, accumulated average loss = 0.318621 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 98
# Run training...
# 527it [00:16, 32.49it/s]
# ** End of epoch, accumulated average loss = 0.317381 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 99
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.317060 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 100
# Run training...
# 527it [00:16, 32.41it/s]
# ** End of epoch, accumulated average loss = 0.315018 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 101
# Run training...
# 527it [00:16, 31.64it/s]
# ** End of epoch, accumulated average loss = 0.315608 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 102
# Run training...
# 527it [00:16, 31.99it/s]
# ** End of epoch, accumulated average loss = 0.314122 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 103
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.313989 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 104
# Run training...
# 527it [00:16, 32.51it/s]
# ** End of epoch, accumulated average loss = 0.314043 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 105
# Run training...
# 527it [00:16, 32.24it/s]
# ** End of epoch, accumulated average loss = 0.313554 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 106
# Run training...
# 527it [00:16, 31.90it/s]
# ** End of epoch, accumulated average loss = 0.313052 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 107
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.311429 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 108
# Run training...
# 527it [00:16, 31.36it/s]
# ** End of epoch, accumulated average loss = 0.311126 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 109
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 0.310071 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 110
# Run training...
# 527it [00:16, 32.28it/s]
# ** End of epoch, accumulated average loss = 0.311042 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 111
# Run training...
# 527it [00:16, 31.17it/s]
# ** End of epoch, accumulated average loss = 0.310073 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 112
# Run training...
# 527it [00:16, 32.04it/s]
# ** End of epoch, accumulated average loss = 0.309733 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 113
# Run training...
# 527it [00:16, 32.07it/s]
# ** End of epoch, accumulated average loss = 0.308289 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 114
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.307876 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 115
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.307853 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 116
# Run training...
# 527it [00:16, 31.69it/s]
# ** End of epoch, accumulated average loss = 0.307834 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 117
# Run training...
# 527it [00:16, 31.49it/s]
# ** End of epoch, accumulated average loss = 0.306845 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 118
# Run training...
# 527it [00:16, 32.23it/s]
# ** End of epoch, accumulated average loss = 0.306035 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 119
# Run training...
# 527it [00:16, 32.62it/s]
# ** End of epoch, accumulated average loss = 0.305643 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 120
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.305009 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 121
# Run training...
# 527it [00:16, 31.85it/s]
# ** End of epoch, accumulated average loss = 0.305641 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 122
# Run training...
# 527it [00:16, 32.10it/s]
# ** End of epoch, accumulated average loss = 0.304752 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 123
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.304648 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 124
# Run training...
# 527it [00:16, 32.72it/s]
# ** End of epoch, accumulated average loss = 0.303125 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 125
# Run training...
# 527it [00:16, 32.10it/s]
# ** End of epoch, accumulated average loss = 0.303868 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 126
# Run training...
# 527it [00:16, 32.15it/s]
# ** End of epoch, accumulated average loss = 0.303009 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 127
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.301797 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 128
# Run training...
# 527it [00:16, 32.16it/s]
# ** End of epoch, accumulated average loss = 0.301576 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 129
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.301595 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 130
# Run training...
# 527it [00:16, 31.36it/s]
# ** End of epoch, accumulated average loss = 0.300766 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 131
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.300700 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 132
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.301139 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 133
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.299719 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 134
# Run training...
# 527it [00:15, 33.07it/s]
# ** End of epoch, accumulated average loss = 0.299888 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 135
# Run training...
# 527it [00:16, 31.94it/s]
# ** End of epoch, accumulated average loss = 0.299764 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 136
# Run training...
# 527it [00:16, 32.48it/s]
# ** End of epoch, accumulated average loss = 0.298701 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 137
# Run training...
# 527it [00:16, 31.90it/s]
# ** End of epoch, accumulated average loss = 0.298215 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 138
# Run training...
# 527it [00:16, 31.75it/s]
# ** End of epoch, accumulated average loss = 0.298266 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 139
# Run training...
# 527it [00:17, 30.96it/s]
# ** End of epoch, accumulated average loss = 0.298728 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 140
# Run training...
# 527it [00:17, 30.95it/s]
# ** End of epoch, accumulated average loss = 0.297720 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 141
# Run training...
# 527it [00:16, 31.04it/s]
# ** End of epoch, accumulated average loss = 0.297155 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 142
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.296598 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 143
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.296245 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 144
# Run training...
# 527it [00:16, 32.12it/s]
# ** End of epoch, accumulated average loss = 0.296481 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 145
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.295890 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 146
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.295088 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 147
# Run training...
# 527it [00:16, 31.18it/s]
# ** End of epoch, accumulated average loss = 0.296169 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 148
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.295454 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 149
# Run training...
# 527it [00:16, 32.07it/s]
# ** End of epoch, accumulated average loss = 0.294762 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 150
# Run training...
# 527it [00:16, 31.86it/s]
# ** End of epoch, accumulated average loss = 0.293942 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 151
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.293602 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 152
# Run training...
# 527it [00:16, 31.47it/s]
# ** End of epoch, accumulated average loss = 0.294221 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 153
# Run training...
# 527it [00:16, 31.56it/s]
# ** End of epoch, accumulated average loss = 0.293022 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 154
# Run training...
# 527it [00:16, 32.12it/s]
# ** End of epoch, accumulated average loss = 0.292367 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 155
# Run training...
# 527it [00:16, 31.98it/s]
# ** End of epoch, accumulated average loss = 0.292919 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 156
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.292884 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 157
# Run training...
# 527it [00:16, 32.00it/s]
# ** End of epoch, accumulated average loss = 0.292283 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 158
# Run training...
# 527it [00:16, 32.62it/s]
# ** End of epoch, accumulated average loss = 0.292823 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 159
# Run training...
# 527it [00:16, 32.30it/s]
# ** End of epoch, accumulated average loss = 0.291830 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 160
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.292424 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 161
# Run training...
# 527it [00:16, 31.68it/s]
# ** End of epoch, accumulated average loss = 0.291678 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 162
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.290781 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 163
# Run training...
# 527it [00:16, 32.20it/s]
# ** End of epoch, accumulated average loss = 0.290929 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 164
# Run training...
# 527it [00:16, 31.78it/s]
# ** End of epoch, accumulated average loss = 0.290446 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 165
# Run training...
# 527it [00:17, 30.95it/s]
# ** End of epoch, accumulated average loss = 0.290560 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 166
# Run training...
# 527it [00:16, 31.95it/s]
# ** End of epoch, accumulated average loss = 0.290474 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 167
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.289975 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 168
# Run training...
# 527it [00:16, 32.71it/s]
# ** End of epoch, accumulated average loss = 0.290184 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 169
# Run training...
# 527it [00:16, 32.10it/s]
# ** End of epoch, accumulated average loss = 0.288853 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 170
# Run training...
# 527it [00:16, 31.55it/s]
# ** End of epoch, accumulated average loss = 0.290097 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 171
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.289119 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 172
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.288810 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 173
# Run training...
# 527it [00:16, 32.77it/s]
# ** End of epoch, accumulated average loss = 0.288259 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 174
# Run training...
# 527it [00:16, 32.29it/s]
# ** End of epoch, accumulated average loss = 0.288553 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 175
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.287608 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 176
# Run training...
# 527it [00:16, 31.59it/s]
# ** End of epoch, accumulated average loss = 0.288032 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 177
# Run training...
# 527it [00:16, 31.42it/s]
# ** End of epoch, accumulated average loss = 0.287801 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 178
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.287307 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 179
# Run training...
# 527it [00:16, 31.40it/s]
# ** End of epoch, accumulated average loss = 0.287087 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 180
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.286985 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 181
# Run training...
# 527it [00:16, 31.91it/s]
# ** End of epoch, accumulated average loss = 0.286781 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 182
# Run training...
# 527it [00:16, 32.31it/s]
# ** End of epoch, accumulated average loss = 0.286365 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 183
# Run training...
# 527it [00:16, 32.07it/s]
# ** End of epoch, accumulated average loss = 0.285746 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 184
# Run training...
# 527it [00:17, 30.83it/s]
# ** End of epoch, accumulated average loss = 0.285447 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 185
# Run training...
# 527it [00:16, 31.76it/s]
# ** End of epoch, accumulated average loss = 0.286177 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 186
# Run training...
# 527it [00:16, 31.00it/s]
# ** End of epoch, accumulated average loss = 0.285790 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 187
# Run training...
# 527it [00:16, 31.18it/s]
# ** End of epoch, accumulated average loss = 0.285548 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 188
# Run training...
# 527it [00:17, 30.90it/s]
# ** End of epoch, accumulated average loss = 0.284836 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 189
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.285126 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 190
# Run training...
# 527it [00:16, 31.89it/s]
# ** End of epoch, accumulated average loss = 0.284538 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 191
# Run training...
# 527it [00:16, 31.81it/s]
# ** End of epoch, accumulated average loss = 0.284358 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 192
# Run training...
# 527it [00:16, 32.67it/s]
# ** End of epoch, accumulated average loss = 0.284238 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 193
# Run training...
# 527it [00:16, 32.07it/s]
# ** End of epoch, accumulated average loss = 0.284314 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 194
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.283753 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 195
# Run training...
# 527it [00:16, 32.24it/s]
# ** End of epoch, accumulated average loss = 0.284154 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 196
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.282982 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 197
# Run training...
# 527it [00:16, 31.86it/s]
# ** End of epoch, accumulated average loss = 0.283121 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 198
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.283766 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 199
# Run training...
# 527it [00:16, 32.13it/s]
# ** End of epoch, accumulated average loss = 0.282420 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 200
# Run training...
# 527it [00:16, 31.88it/s]
# ** End of epoch, accumulated average loss = 0.283396 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 201
# Run training...
# 527it [00:16, 32.50it/s]
# ** End of epoch, accumulated average loss = 0.282556 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 202
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.281814 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 203
# Run training...
# 527it [00:16, 32.20it/s]
# ** End of epoch, accumulated average loss = 0.282833 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 204
# Run training...
# 527it [00:16, 31.58it/s]
# ** End of epoch, accumulated average loss = 0.282241 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 205
# Run training...
# 527it [00:16, 32.50it/s]
# ** End of epoch, accumulated average loss = 0.281758 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 206
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.281498 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 207
# Run training...
# 527it [00:16, 32.77it/s]
# ** End of epoch, accumulated average loss = 0.281399 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 208
# Run training...
# 527it [00:16, 31.59it/s]
# ** End of epoch, accumulated average loss = 0.281395 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 209
# Run training...
# 527it [00:16, 31.89it/s]
# ** End of epoch, accumulated average loss = 0.281149 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 210
# Run training...
# 527it [00:16, 32.25it/s]
# ** End of epoch, accumulated average loss = 0.280802 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 211
# Run training...
# 527it [00:16, 32.28it/s]
# ** End of epoch, accumulated average loss = 0.280066 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 212
# Run training...
# 527it [00:16, 32.76it/s]
# ** End of epoch, accumulated average loss = 0.280580 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 213
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.280071 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 214
# Run training...
# 527it [00:16, 32.36it/s]
# ** End of epoch, accumulated average loss = 0.280842 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 215
# Run training...
# 527it [00:16, 32.35it/s]
# ** End of epoch, accumulated average loss = 0.279309 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 216
# Run training...
# 527it [00:16, 32.08it/s]
# ** End of epoch, accumulated average loss = 0.280395 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 217
# Run training...
# 527it [00:16, 32.66it/s]
# ** End of epoch, accumulated average loss = 0.281005 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 218
# Run training...
# 527it [00:16, 32.10it/s]
# ** End of epoch, accumulated average loss = 0.279355 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 219
# Run training...
# 527it [00:16, 32.03it/s]
# ** End of epoch, accumulated average loss = 0.279178 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 220
# Run training...
# 527it [00:16, 32.31it/s]
# ** End of epoch, accumulated average loss = 0.278818 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 221
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.278681 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 222
# Run training...
# 527it [00:16, 32.72it/s]
# ** End of epoch, accumulated average loss = 0.278195 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 223
# Run training...
# 527it [00:16, 32.28it/s]
# ** End of epoch, accumulated average loss = 0.278722 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 224
# Run training...
# 527it [00:16, 32.24it/s]
# ** End of epoch, accumulated average loss = 0.279025 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 225
# Run training...
# 527it [00:16, 31.94it/s]
# ** End of epoch, accumulated average loss = 0.277821 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 226
# Run training...
# 527it [00:16, 32.47it/s]
# ** End of epoch, accumulated average loss = 0.277929 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 227
# Run training...
# 527it [00:15, 33.00it/s]
# ** End of epoch, accumulated average loss = 0.277960 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 228
# Run training...
# 527it [00:16, 32.23it/s]
# ** End of epoch, accumulated average loss = 0.277845 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 229
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.278216 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 230
# Run training...
# 527it [00:16, 31.99it/s]
# ** End of epoch, accumulated average loss = 0.277440 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 231
# Run training...
# 527it [00:16, 32.17it/s]
# ** End of epoch, accumulated average loss = 0.278235 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 232
# Run training...
# 527it [00:15, 33.01it/s]
# ** End of epoch, accumulated average loss = 0.277391 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 233
# Run training...
# 527it [00:16, 31.84it/s]
# ** End of epoch, accumulated average loss = 0.277501 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 234
# Run training...
# 527it [00:16, 32.31it/s]
# ** End of epoch, accumulated average loss = 0.276769 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 235
# Run training...
# 527it [00:16, 32.11it/s]
# ** End of epoch, accumulated average loss = 0.277181 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 236
# Run training...
# 527it [00:16, 32.10it/s]
# ** End of epoch, accumulated average loss = 0.276651 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 237
# Run training...
# 527it [00:16, 32.84it/s]
# ** End of epoch, accumulated average loss = 0.276054 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 238
# Run training...
# 527it [00:16, 32.21it/s]
# ** End of epoch, accumulated average loss = 0.276027 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 239
# Run training...
# 527it [00:16, 32.62it/s]
# ** End of epoch, accumulated average loss = 0.275711 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 240
# Run training...
# 527it [00:16, 31.67it/s]
# ** End of epoch, accumulated average loss = 0.275913 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 241
# Run training...
# 527it [00:16, 32.48it/s]
# ** End of epoch, accumulated average loss = 0.275691 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 242
# Run training...
# 527it [00:16, 32.34it/s]
# ** End of epoch, accumulated average loss = 0.275940 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 243
# Run training...
# 527it [00:16, 32.19it/s]
# ** End of epoch, accumulated average loss = 0.275232 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 244
# Run training...
# 527it [00:16, 32.29it/s]
# ** End of epoch, accumulated average loss = 0.274611 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 245
# Run training...
# 527it [00:16, 31.87it/s]
# ** End of epoch, accumulated average loss = 0.275214 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 246
# Run training...
# 527it [00:16, 31.80it/s]
# ** End of epoch, accumulated average loss = 0.275155 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 247
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.275160 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 248
# Run training...
# 527it [00:16, 31.12it/s]
# ** End of epoch, accumulated average loss = 0.275180 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 249
# Run training...
# 527it [00:16, 31.85it/s]
# ** End of epoch, accumulated average loss = 0.274358 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 250
# Run training...
# 527it [00:16, 32.27it/s]
# ** End of epoch, accumulated average loss = 0.274250 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 251
# Run training...
# 527it [00:16, 32.30it/s]
# ** End of epoch, accumulated average loss = 0.274072 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 252
# Run training...
# 527it [00:16, 32.25it/s]
# ** End of epoch, accumulated average loss = 0.273808 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 253
# Run training...
# 527it [00:16, 31.37it/s]
# ** End of epoch, accumulated average loss = 0.274704 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 254
# Run training...
# 527it [00:16, 31.47it/s]
# ** End of epoch, accumulated average loss = 0.273390 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 255
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.273323 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 256
# Run training...
# 527it [00:16, 31.91it/s]
# ** End of epoch, accumulated average loss = 0.273728 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 257
# Run training...
# 527it [00:16, 32.14it/s]
# ** End of epoch, accumulated average loss = 0.272978 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 258
# Run training...
# 527it [00:16, 32.33it/s]
# ** End of epoch, accumulated average loss = 0.273188 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 259
# Run training...
# 527it [00:16, 31.52it/s]
# ** End of epoch, accumulated average loss = 0.273456 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 260
# Run training...
# 527it [00:16, 31.88it/s]
# ** End of epoch, accumulated average loss = 0.273385 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 261
# Run training...
# 527it [00:16, 32.39it/s]
# ** End of epoch, accumulated average loss = 0.272972 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 262
# Run training...
# 527it [00:16, 32.51it/s]
# ** End of epoch, accumulated average loss = 0.272623 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 263
# Run training...
# 527it [00:16, 31.98it/s]
# ** End of epoch, accumulated average loss = 0.272323 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 264
# Run training...
# 527it [00:16, 32.35it/s]
# ** End of epoch, accumulated average loss = 0.272694 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 265
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.272687 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 266
# Run training...
# 527it [00:16, 32.44it/s]
# ** End of epoch, accumulated average loss = 0.272397 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 267
# Run training...
# 527it [00:16, 32.64it/s]
# ** End of epoch, accumulated average loss = 0.272332 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 268
# Run training...
# 527it [00:16, 32.23it/s]
# ** End of epoch, accumulated average loss = 0.271492 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 269
# Run training...
# 527it [00:16, 32.36it/s]
# ** End of epoch, accumulated average loss = 0.271666 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 270
# Run training...
# 527it [00:16, 32.24it/s]
# ** End of epoch, accumulated average loss = 0.271579 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 271
# Run training...
# 527it [00:16, 32.48it/s]
# ** End of epoch, accumulated average loss = 0.271481 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 272
# ...
#
# ----------------------------------------
# Epoch: 516
# Run training...
# 527it [00:16, 31.35it/s]
# ** End of epoch, accumulated average loss = 0.247831 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 517
# Run training...
# 527it [00:16, 31.81it/s]
# ** End of epoch, accumulated average loss = 0.247511 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 518
# Run training...
# 527it [00:16, 31.76it/s]
# ** End of epoch, accumulated average loss = 0.248086 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 519
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.248584 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 520
# Run training...
# 527it [00:16, 31.70it/s]
# ** End of epoch, accumulated average loss = 0.247965 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 521
# Run training...
# 527it [00:17, 30.23it/s]
# ** End of epoch, accumulated average loss = 0.248482 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 522
# Run training...
# 527it [00:17, 29.82it/s]
# ** End of epoch, accumulated average loss = 0.248070 **
# ** Elapsed time: 0:00:18**
#
# ----------------------------------------
# Epoch: 523
# Run training...
# 527it [00:17, 30.34it/s]
# ** End of epoch, accumulated average loss = 0.248168 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 524
# Run training...
# 527it [00:16, 31.38it/s]
# ** End of epoch, accumulated average loss = 0.247357 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 525
# Run training...
# 527it [00:16, 31.50it/s]
# ** End of epoch, accumulated average loss = 0.248436 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 526
# Run training...
# 527it [00:16, 31.30it/s]
# ** End of epoch, accumulated average loss = 0.246869 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 527
# Run training...
# 527it [00:17, 30.98it/s]
# ** End of epoch, accumulated average loss = 0.247393 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 528
# Run training...
# 527it [00:16, 31.95it/s]
# ** End of epoch, accumulated average loss = 0.247806 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 529
# Run training...
# 527it [00:16, 31.05it/s]
# ** End of epoch, accumulated average loss = 0.247038 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 530
# Run training...
# 527it [00:16, 31.26it/s]
# ** End of epoch, accumulated average loss = 0.246469 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 531
# Run training...
# 527it [00:16, 32.39it/s]
# ** End of epoch, accumulated average loss = 0.247543 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 532
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.247454 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 533
# Run training...
# 527it [00:16, 32.41it/s]
# ** End of epoch, accumulated average loss = 0.247116 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 534
# Run training...
# 527it [00:16, 31.85it/s]
# ** End of epoch, accumulated average loss = 0.247341 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 535
# Run training...
# 527it [00:16, 31.46it/s]
# ** End of epoch, accumulated average loss = 0.246935 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 536
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.247367 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 537
# Run training...
# 527it [00:16, 32.47it/s]
# ** End of epoch, accumulated average loss = 0.247633 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 538
# Run training...
# 527it [00:16, 32.46it/s]
# ** End of epoch, accumulated average loss = 0.246636 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 539
# Run training...
# 527it [00:16, 31.91it/s]
# ** End of epoch, accumulated average loss = 0.247080 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 540
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.246789 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 541
# Run training...
# 527it [00:16, 31.52it/s]
# ** End of epoch, accumulated average loss = 0.247300 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 542
# Run training...
# 527it [00:16, 31.85it/s]
# ** End of epoch, accumulated average loss = 0.246435 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 543
# Run training...
# 527it [00:16, 32.43it/s]
# ** End of epoch, accumulated average loss = 0.246730 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 544
# Run training...
# 527it [00:16, 31.37it/s]
# ** End of epoch, accumulated average loss = 0.247024 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 545
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.246596 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 546
# Run training...
# 527it [00:16, 31.97it/s]
# ** End of epoch, accumulated average loss = 0.246510 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 547
# Run training...
# 527it [00:16, 32.05it/s]
# ** End of epoch, accumulated average loss = 0.245973 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 548
# Run training...
# 527it [00:16, 32.62it/s]
# ** End of epoch, accumulated average loss = 0.247503 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 549
# Run training...
# 527it [00:16, 32.03it/s]
# ** End of epoch, accumulated average loss = 0.246487 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 550
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 0.246101 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 551
# Run training...
# 527it [00:16, 31.72it/s]
# ** End of epoch, accumulated average loss = 0.246194 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 552
# Run training...
# 527it [00:16, 32.68it/s]
# ** End of epoch, accumulated average loss = 0.246002 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 553
# Run training...
# 527it [00:16, 31.96it/s]
# ** End of epoch, accumulated average loss = 0.245830 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 554
# Run training...
# 527it [00:16, 32.37it/s]
# ** End of epoch, accumulated average loss = 0.245700 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 555
# Run training...
# 527it [00:16, 31.82it/s]
# ** End of epoch, accumulated average loss = 0.246338 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 556
# Run training...
# 527it [00:16, 31.53it/s]
# ** End of epoch, accumulated average loss = 0.245771 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 557
# Run training...
# 527it [00:16, 32.20it/s]
# ** End of epoch, accumulated average loss = 0.246126 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 558
# Run training...
# 527it [00:16, 32.01it/s]
# ** End of epoch, accumulated average loss = 0.245675 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 559
# Run training...
# 527it [00:17, 30.86it/s]
# ** End of epoch, accumulated average loss = 0.245653 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 560
# Run training...
# 527it [00:16, 31.62it/s]
# ** End of epoch, accumulated average loss = 0.245231 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 561
# Run training...
# 527it [00:16, 31.41it/s]
# ** End of epoch, accumulated average loss = 0.245394 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 562
# Run training...
# 527it [00:16, 31.83it/s]
# ** End of epoch, accumulated average loss = 0.245349 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 563
# Run training...
# 527it [00:16, 31.14it/s]
# ** End of epoch, accumulated average loss = 0.246156 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 564
# Run training...
# 527it [00:16, 32.03it/s]
# ** End of epoch, accumulated average loss = 0.245768 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 565
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 0.245086 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 566
# Run training...
# 527it [00:16, 31.66it/s]
# ** End of epoch, accumulated average loss = 0.244719 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 567
# Run training...
# 527it [00:16, 31.34it/s]
# ** End of epoch, accumulated average loss = 0.245988 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 568
# Run training...
# 527it [00:16, 31.61it/s]
# ** End of epoch, accumulated average loss = 0.244796 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 569
# Run training...
# 527it [00:16, 31.86it/s]
# ** End of epoch, accumulated average loss = 0.244821 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 570
# Run training...
# 527it [00:16, 31.18it/s]
# ** End of epoch, accumulated average loss = 0.245015 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 571
# Run training...
# 527it [00:16, 31.44it/s]
# ** End of epoch, accumulated average loss = 0.245114 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 572
# Run training...
# 527it [00:16, 32.35it/s]
# ** End of epoch, accumulated average loss = 0.245355 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 573
# Run training...
# 527it [00:16, 31.90it/s]
# ** End of epoch, accumulated average loss = 0.245310 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 574
# Run training...
# 527it [00:16, 31.47it/s]
# ** End of epoch, accumulated average loss = 0.244521 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 575
# Run training...
# 527it [00:16, 31.79it/s]
# ** End of epoch, accumulated average loss = 0.244813 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 576
# Run training...
# 527it [00:16, 31.77it/s]
# ** End of epoch, accumulated average loss = 0.244200 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 577
# Run training...
# 527it [00:16, 32.43it/s]
# ** End of epoch, accumulated average loss = 0.245002 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 578
# Run training...
# 527it [00:16, 32.12it/s]
# ** End of epoch, accumulated average loss = 0.244899 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 579
# Run training...
# 527it [00:16, 32.14it/s]
# ** End of epoch, accumulated average loss = 0.243967 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 580
# Run training...
# 527it [00:16, 32.11it/s]
# ** End of epoch, accumulated average loss = 0.245007 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 581
# Run training...
# 527it [00:16, 31.28it/s]
# ** End of epoch, accumulated average loss = 0.243897 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 582
# Run training...
# 527it [00:16, 32.09it/s]
# ** End of epoch, accumulated average loss = 0.244405 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 583
# Run training...
# 527it [00:16, 31.35it/s]
# ** End of epoch, accumulated average loss = 0.244054 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 584
# Run training...
# 527it [00:16, 32.17it/s]
# ** End of epoch, accumulated average loss = 0.244695 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 585
# Run training...
# 527it [00:16, 31.53it/s]
# ** End of epoch, accumulated average loss = 0.244242 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 586
# Run training...
# 527it [00:16, 32.21it/s]
# ** End of epoch, accumulated average loss = 0.244078 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 587
# Run training...
# 527it [00:16, 32.52it/s]
# ** End of epoch, accumulated average loss = 0.244051 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 588
# Run training...
# 527it [00:16, 32.02it/s]
# ** End of epoch, accumulated average loss = 0.244197 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 589
# Run training...
# 527it [00:16, 32.14it/s]
# ** End of epoch, accumulated average loss = 0.243861 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 590
# Run training...
# 527it [00:16, 31.74it/s]
# ** End of epoch, accumulated average loss = 0.243771 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 591
# Run training...
# 527it [00:16, 32.29it/s]
# ** End of epoch, accumulated average loss = 0.243523 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 592
# Run training...
# 527it [00:16, 32.06it/s]
# ** End of epoch, accumulated average loss = 0.243442 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 593
# Run training...
# 527it [00:16, 32.08it/s]
# ** End of epoch, accumulated average loss = 0.243562 **
# ** Elapsed time: 0:00:16**
#
# ----------------------------------------
# Epoch: 594
# Run training...
# 527it [00:16, 31.65it/s]
# ** End of epoch, accumulated average loss = 0.244539 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 595
# Run training...
# 527it [00:16, 31.08it/s]
# ** End of epoch, accumulated average loss = 0.242863 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 596
# Run training...
# 527it [00:16, 31.71it/s]
# ** End of epoch, accumulated average loss = 0.244306 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 597
# Run training...
# 527it [00:16, 31.28it/s]
# ** End of epoch, accumulated average loss = 0.243814 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 598
# Run training...
# 527it [00:17, 30.94it/s]
# ** End of epoch, accumulated average loss = 0.243582 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 599
# Run training...
# 527it [00:17, 30.64it/s]
# ** End of epoch, accumulated average loss = 0.243478 **
# ** Elapsed time: 0:00:17**
#
# ----------------------------------------
# Epoch: 600
# Run training...
# 527it [00:16, 31.63it/s]
# ** End of epoch, accumulated average loss = 0.244053 **
# ** Elapsed time: 0:00:17**
# Classifier trained in 9960.89s
#
# Classifying train set with 105371 examples ...
# Using GPU device: cuda
# 100% 527/527 [01:20<00:00,  6.56it/s]
# train set classified in 80.36s
#
# Classifying dev set with 26342 examples ...
# Using GPU device: cuda
# 100% 132/132 [00:19<00:00,  6.68it/s]
# dev set classified in 19.77s
#
# Classifying train_small set with 2000 examples ...
# Using GPU device: cuda
# 100% 10/10 [00:01<00:00,  6.63it/s]
# train_small set classified in 1.51s
#
# Classifying dev_small set with 2000 examples ...
# Using GPU device: cuda
# 100% 10/10 [00:01<00:00,  6.38it/s]
# dev_small set classified in 1.57s
#
# Classifying test set with 32926 examples ...
# Using GPU device: cuda
# 100% 165/165 [00:25<00:00,  6.58it/s]
# test set classified in 25.08s
# Predictions saved to preds_translit.tsv
#
# Checking saved predictions ...
# train set accuracy@1: 0.71
# dev set accuracy@1: 0.67
# train_small set accuracy@1: 0.71
# dev_small set accuracy@1: 0.68
# no labels for test set
